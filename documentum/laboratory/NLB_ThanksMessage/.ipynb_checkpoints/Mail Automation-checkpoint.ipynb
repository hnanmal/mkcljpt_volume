# %%
# @font-face {
#     font-family: 'RIDIBatang';
#     src: url('https://cdn.jsdelivr.net/gh/projectnoonnu/noonfonts_twelve@1.0/RIDIBatang.woff') format('woff');
#     font-weight: normal;
#     font-style: normal;
# }

# %%
# @font-face {
#     font-family: 'NotoSerifKR';
#     src: url('https://cdn.jsdelivr.net/gh/projectnoonnu/noonfonts_two@1.0/NotoSerifKR.woff') format('woff');
#     font-weight: normal;
#     font-style: normal;
# }

# %%
# # https://ibb.co/LQyQxf9
# # https://ibb.co/wyMFNHW
# # https://ibb.co/VYSq1M9

# # 고마워요
# https://i.ibb.co/YBkLCfQ/img-thanks.jpg
# # 힘내세요
# https://i.ibb.co/mvKv97h/img-cheer.jpg 
# # 수고했어요
# https://i.ibb.co/rk4RGP6/img-goodjob.jpg

# %% [markdown]
# # Excel Import

# %%
import csv
from dataclasses import dataclass, field, asdict, astuple
from typing import List
from collections import namedtuple
from functools import reduce
from functools import partial
import math
import matplotlib.pyplot as plt
import numpy as np
import random

import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText

# %%
def importCSV(_path):
    with open(_path,'r') as f:
        reader  = csv.reader(f) # csv의 행별로 읽어옴
        res = [x for x in reader]
        
    return res

def exportCSV(_filename, _datas):
    f = open(_filename, 'w', newline='') # 자동줄바꿈 방지 header 이후 첫행 빈행 생성 방지
    csv_writer = csv.writer(f)
    
    for x in _datas:
        csv_writer.writerow(x)
    f.close()

# %%
input_path = '20231215_all_data_최종_메일송부용_사번_최종누락만.csv'

# %%
allDatas = importCSV(input_path)
allDatas
# Out:
# [['\ufeff[NLB] 협업 감사 메시지 EVENT',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['',
#   '',
#   '',
#   '',
#   'P1B1',
#   'P2B4',
#   '',
#   '',
#   '',
#   'P2B5',
#   'P2B6',
#   'P2B8',
#   '',
#   '',
#   'P2B9',
#   'P2B10',
#   'P2B11',
#   '글자수',
#   '글자수 순위',
#   '픽'],
#  ['응답자ID',
#   '답변 확인 고유번호',
#   '시작일시',
#   '종료일시',
#   '어떤 마음을 전달해드릴까요? 카드를 선택하세요.',
#   '본인의 성명과 직급을 작성해주세요.',
#   '발신자 이름',
#   '발신자 사번',
#   '',
#   '현재 근무지를 입력해주세요.',
#   '현재 소속 팀과 근무지를 입력해주세요.',
#   '수신인의 성명과 직급을 작성해주세요.',
#   '수신자 이름',
#   '수신자 사번',
#   '수신인의 현재 근무지를 입력해주세요.',
#   '수신인이 속한 팀과 근무지를 입력해주세요.',
#   '전달하고 싶은 메시지 (고마워요 / 힘내세요 / 수고했어요)',
#   '글자수',
#   '글자수 순위',
#   '픽'],
#  ['',
#   '',
#   '',
#   '',
#   '응답',
#   '',
#   '',
#   '',
#   '',
#   '응답',
#   '',
#   '',
#   '',
#   '',
#   '응답',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['16',
#   '446-67-12693',
#   '2023-12-05 7:48',
#   '2023-12-05 7:52',
#   '[IMAGE] 고마워요',
#   '최유리 매니저',
#   '최유리',
#   '2327330',
#   '',
#   '서울사무소',
#   '사우디아미랄프로젝트',
#   '김태권 매니저',
#   '김태권',
#   '2121246',
#   '본사',
#   '재무관리실 / 회계팀',
#   '항상 친절하게 알려줘서 고마워요👍',
#   '19',
#   '476',
#   ''],
#  ['22',
#   '922-69-84397',
#   '2023-12-05 8:24',
#   '2023-12-05 8:27',
#   '[IMAGE] 수고했어요',
#   '최선애 매니저',
#   '최선애',
#   '2212510',
#   '',
#   '본사',
#   'P2E팀',
#   '이동희 책임매니저',
#   '이동희',
#   '2205126',
#   '국내현장',
#   '플랜트 수행실 사우디 SACE2 프로젝트',
#   '책임님! 공인중개사 시험 준비할 때 응원해주셔서 감사합니다!! 그 응원덕에 붙을 수 있었습니다!! 내년엔 책임님도 공인중개사 합격!!입니다!!',
#   '79',
#   '207',
#   ''],
#  ['28',
#   '853-11-58159',
#   '2023-12-05 17:33',
#   '2023-12-05 17:36',
#   '[IMAGE] 힘내세요',
#   '신민재 매니저',
#   '신민재',
#   '1600925',
#   '',
#   '본사',
#   '건축전기팀 / 본사',
#   '조성은 매니저',
#   '조성은',
#   '1923083',
#   '본사',
#   '건축전기팀 / 본사',
#   'NLB & 설계업무 병행하기 힘들었을텐데, 올 한해 고생많았습니다.\n업무에 열정적인 모습이 보기좋아요!\n내년에도 화이팅하자구요!!',
#   '72',
#   '225',
#   ''],
#  ['48',
#   '846-14-11560',
#   '2023-12-06 7:51',
#   '2023-12-06 7:56',
#   '[IMAGE] 고마워요',
#   '김지훈 대리',
#   '김지훈',
#   '2101753',
#   '',
#   '국내현장',
#   '자산현장1팀/현대차 동대구지점',
#   '손병준 FM사업소장',
#   '손병준',
#   '1910165',
#   '국내현장',
#   '자산현장1팀/영남순회사무소',
#   '소장님\n올 한해도 많은 도움과 협조\n감사합니다\n23년 마무리 잘하시고\n24년에도 힘내시고\n화이팅 ^~^',
#   '57',
#   '262',
#   ''],
#  ['69',
#   '162-80-78794',
#   '2023-12-06 8:37',
#   '2023-12-06 8:46',
#   '[IMAGE] 수고했어요',
#   '이재학 매니저',
#   '이재학',
#   '1501872',
#   '',
#   '해외현장',
#   '플랜트배관설계팀/인도네시아IKAN현장',
#   '강창현 파트장',
#   '강창현',
#   '1595395',
#   '해외현장',
#   '플랜트배관설계팀/인도네시아IKAN현장',
#   '하루하루 바쁜 현장에서, 후배 사원들을 따듯하게 챙겨주셔서 감사합니다!\n올 한해도 고생 많으셨습니다~',
#   '56',
#   '265',
#   ''],
#  ['72',
#   '301-90-26495',
#   '2023-12-06 8:46',
#   '2023-12-06 8:48',
#   '[IMAGE] 고마워요',
#   '최한비 매니저',
#   '최한비',
#   '2318236',
#   '',
#   '국내현장',
#   'Building Design팀/광명기아현장',
#   '김래영 매니저',
#   '김래영',
#   '2216615',
#   '국내현장',
#   'Building Design팀/광명기아현장',
#   '래용 매니저님~! 행복하고 배부른 연말을 보내요 우리,,',
#   '31',
#   '408',
#   ''],
#  ['79',
#   '510-98-65374',
#   '2023-12-06 8:53',
#   '2023-12-06 8:53',
#   '[IMAGE] 고마워요',
#   '이상훈 책임매니저',
#   '이상훈',
#   '1501771',
#   '',
#   '본사',
#   '플랜트설계관리팀 / 본사',
#   '이재민 책임매니저',
#   '이재민',
#   '1439030',
#   '본사',
#   '플랜트설계관리팀 / 본사',
#   '2023년 한해 수고 많으셨습니다. 감사합니다.',
#   '26',
#   '426',
#   ''],
#  ['80',
#   '655-13-71116',
#   '2023-12-06 8:53',
#   '2023-12-06 8:54',
#   '[IMAGE] 고마워요',
#   '이상훈 책임매니저',
#   '이상훈',
#   '1501771',
#   '',
#   '본사',
#   '플랜트설계관리팀 / 본사',
#   '전미영 매니저',
#   '전미영',
#   '2222035',
#   '본사',
#   '플랜트설계관리팀 / 본사',
#   '2023년 한해 수고 많으셨습니다. 감사합니다.',
#   '26',
#   '426',
#   ''],
#  ['83',
#   '578-07-46540',
#   '2023-12-06 8:55',
#   '2023-12-06 8:55',
#   '[IMAGE] 힘내세요',
#   '이상훈 책임매니저',
#   '이상훈',
#   '1501771',
#   '',
#   '본사',
#   '플랜트설계관리팀 / 본사',
#   '강혜진 책임매니저',
#   '강혜진',
#   '0704536',
#   '본사',
#   'GEC설립추진TFT / 본사',
#   '2023년 한해 수고 많으셨습니다. 감사합니다.',
#   '26',
#   '426',
#   ''],
#  ['84',
#   '964-39-88095',
#   '2023-12-06 8:55',
#   '2023-12-06 8:56',
#   '[IMAGE] 힘내세요',
#   '이상훈 책임매니저',
#   '이상훈',
#   '1501771',
#   '',
#   '본사',
#   '플랜트설계관리팀 / 본사',
#   '강주은 매니저',
#   '강주은',
#   '1119596',
#   '본사',
#   '플랜트설계관리팀 / 본사',
#   '2023년 한해 수고 많으셨습니다. 감사합니다.',
#   '26',
#   '426',
#   ''],
#  ['87',
#   '275-28-79554',
#   '2023-12-06 8:41',
#   '2023-12-06 8:58',
#   '[IMAGE] 고마워요',
#   '이영섭 책임매니저',
#   '이영섭',
#   '1501813',
#   '',
#   '본사',
#   '플랜트설계관리팀 / 본사',
#   '이상훈 책임매니저',
#   '이상훈',
#   '1501771',
#   '본사',
#   '플랜트설계관리팀 / 본사',
#   '항상 올바른 지도 편달에 감사드립니다! 충성 충성!!',
#   '29',
#   '416',
#   ''],
#  ['91',
#   '221-71-21442',
#   '2023-12-06 8:57',
#   '2023-12-06 9:00',
#   '[IMAGE] 고마워요',
#   '이동길 FM과장',
#   '이동길',
#   '1505944',
#   '',
#   '국내현장',
#   '자산현장1팀/HMC사상하이테크센터',
#   '양정호 책임매니저',
#   '양정호',
#   '1400881',
#   '본사',
#   '자산안전팀',
#   '올해도 수고 많으셨습니다~',
#   '14',
#   '486',
#   ''],
#  ['92',
#   '757-05-60996',
#   '2023-12-06 8:59',
#   '2023-12-06 9:01',
#   '[IMAGE] 고마워요',
#   '한대희 매니저',
#   '한대희',
#   '9921149',
#   '',
#   '본사',
#   '자산상품개발TFT',
#   '윤주성 매니저',
#   '윤주성',
#   '1438163',
#   '본사',
#   '자산상품개발TFT',
#   '우리 사수 매니저님!\n진심이 느껴지는 조언들 항상 감사합니다!!',
#   '35',
#   '402',
#   ''],
#  ['104',
#   '341-26-24374',
#   '2023-12-06 9:06',
#   '2023-12-06 9:06',
#   '[IMAGE] 고마워요',
#   '이상훈 책임매니저',
#   '이상훈',
#   '1501771',
#   '',
#   '본사',
#   '플랜트설계관리팀 / 본사',
#   '송정은 매니저',
#   '송정은',
#   '1004892',
#   '본사',
#   '지속가능경영팀 / 본사',
#   '2023년 한해 수고 많으셨습니다. 감사합니다.',
#   '26',
#   '426',
#   ''],
#  ['138',
#   '125-39-22008',
#   '2023-12-06 9:19',
#   '2023-12-06 9:20',
#   '[IMAGE] 힘내세요',
#   '이상훈 책임매니저',
#   '이상훈',
#   '1501771',
#   '',
#   '본사',
#   '플랜트설계관리팀 / 본사',
#   '장경선 책임매니저',
#   '장경선',
#   '1118121',
#   '본사',
#   '플랜트설계관리팀 / 본사',
#   '2023년 한해 수고 많으셨습니다. 감사합니다.',
#   '26',
#   '426',
#   ''],
#  ['148',
#   '747-43-38844',
#   '2023-12-06 9:47',
#   '2023-12-06 9:49',
#   '[IMAGE] 고마워요',
#   '이동길 FM과장',
#   '이동길',
#   '1505944',
#   '',
#   '국내현장',
#   '자산현장1팀/HMC사상하이테크',
#   '김철민 책임매니저',
#   '김철민',
#   '1627433',
#   '본사',
#   '자산안전팀',
#   '언제 열일 하시는 김책임님~\n행복한 연말 보내세요~',
#   '28',
#   '421',
#   ''],
#  ['214',
#   '462-12-11373',
#   '2023-12-11 8:43',
#   '2023-12-11 8:53',
#   '[IMAGE] 힘내세요',
#   '윤성한 소장',
#   '윤성한',
#   '2025703',
#   '',
#   '국내현장',
#   '자산현장3팀/ 트랜시스 화성구동연구소',
#   '김기연 대리',
#   '김기연',
#   '2226596',
#   '국내현장',
#   '자산현장3팀 / 트랜시스 화성구동연구소',
#   '경력 신입사원으로 입사해 화성구동연구소 \n현장으로 발령 받은지 엊그제 같은데 벌써 1년이 넘었네요. 45살이면 적은 나이도 아닌데 현장 \n막내로써 잡다한 업무처리와 긍정적인 마인드로 업무에 임해주고 있어 항상 감사합니다. \n얼마 남지않은 23년 마무리 잘하고 24년 진일보 할수있는 새해가 되도록 계획 잘 세우고 목표 달성 할수 있도록 서로 노력합시다. 화이팀~~^^',
#   '205',
#   '25',
#   ''],
#  ['249',
#   '938-10-05900',
#   '2023-12-11 14:53',
#   '2023-12-11 14:55',
#   '[IMAGE] 수고했어요',
#   '강주은 매니저',
#   '강주은',
#   '1119596',
#   '',
#   '본사',
#   '플랜트설계관리팀/본사',
#   '손병규 팀장',
#   '손병규',
#   '9934299',
#   '본사',
#   '플랜트설계관리팀/본사',
#   '손병규 팀장님\n늘 직원들을 배려하는 마음으로 부서 업무에 힘써 주셔서 감사합니다\n올 한해도 수고 많으셨습니다~!!',
#   '63',
#   '254',
#   ''],
#  ['318',
#   '294-08-25940',
#   '2023-12-14 6:54',
#   '2023-12-14 6:55',
#   '[IMAGE] 고마워요',
#   '류한정 책임',
#   '류한정',
#   '1000592',
#   '',
#   '본사',
#   '경영기획팀',
#   '이희동 책임',
#   '이희동',
#   '0852163',
#   '본사',
#   '인력운영팀',
#   '올 한해 바쁘신 와중에 많은 도움을 주셔서 감사합니다. 내년에도 잘 부탁드립니다.',
#   '45',
#   '309',
#   ''],
#  ['402',
#   '352-37-79694',
#   '2023-12-14 9:17',
#   '2023-12-14 9:31',
#   '[IMAGE] 수고했어요',
#   '김승우 매니저',
#   '김승우',
#   '2301070',
#   '',
#   '국내현장',
#   '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   '서용하 책임매니저, 김동호 책임매니저, 이성옥 책임매니저, 최신희 매니저, 남궁혜린 매니저',
#   '서용하',
#   '2213136',
#   '국내현장',
#   '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   '팀장님 그리고 책임님, 매니저님\n안녕하세요!\n\n신입사원으로 입사하여 현장에 부임한지 \n약 1년이라는 시간 동안 팀장님을 비롯하여 \n많은 분들께서 이해해 주시고 이쁘게 봐주셔서 \n감사합니다\n\n올 한 해 정말 고생 많으셨습니다\n남은 준공까지 더 열심히 하는 \n막내가 되겠습니다😊',
#   '154',
#   '41',
#   ''],
#  ['402',
#   '352-37-79694',
#   '2023-12-14 9:17',
#   '2023-12-14 9:31',
#   '[IMAGE] 수고했어요',
#   '김승우 매니저',
#   '김승우',
#   '2301070',
#   '',
#   '국내현장',
#   '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   '서용하 책임매니저, 김동호 책임매니저, 이성옥 책임매니저, 최신희 매니저, 남궁혜린 매니저',
#   '김동호',
#   '2201675',
#   '국내현장',
#   '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   '팀장님 그리고 책임님, 매니저님\n안녕하세요!\n\n신입사원으로 입사하여 현장에 부임한지 \n약 1년이라는 시간 동안 팀장님을 비롯하여 \n많은 분들께서 이해해 주시고 이쁘게 봐주셔서 \n감사합니다\n\n올 한 해 정말 고생 많으셨습니다\n남은 준공까지 더 열심히 하는 \n막내가 되겠습니다😊',
#   '154',
#   '41',
#   ''],
#  ['402',
#   '352-37-79694',
#   '2023-12-14 9:17',
#   '2023-12-14 9:31',
#   '[IMAGE] 수고했어요',
#   '김승우 매니저',
#   '김승우',
#   '2301070',
#   '',
#   '국내현장',
#   '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   '서용하 책임매니저, 김동호 책임매니저, 이성옥 책임매니저, 최신희 매니저, 남궁혜린 매니저',
#   '이성옥',
#   '2310946',
#   '국내현장',
#   '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   '팀장님 그리고 책임님, 매니저님\n안녕하세요!\n\n신입사원으로 입사하여 현장에 부임한지 \n약 1년이라는 시간 동안 팀장님을 비롯하여 \n많은 분들께서 이해해 주시고 이쁘게 봐주셔서 \n감사합니다\n\n올 한 해 정말 고생 많으셨습니다\n남은 준공까지 더 열심히 하는 \n막내가 되겠습니다😊',
#   '154',
#   '41',
#   ''],
#  ['402',
#   '352-37-79694',
#   '2023-12-14 9:17',
#   '2023-12-14 9:31',
#   '[IMAGE] 수고했어요',
#   '김승우 매니저',
#   '김승우',
#   '2301070',
#   '',
#   '국내현장',
#   '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   '서용하 책임매니저, 김동호 책임매니저, 이성옥 책임매니저, 최신희 매니저, 남궁혜린 매니저',
#   '최신희',
#   '2213432',
#   '국내현장',
#   '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   '팀장님 그리고 책임님, 매니저님\n안녕하세요!\n\n신입사원으로 입사하여 현장에 부임한지 \n약 1년이라는 시간 동안 팀장님을 비롯하여 \n많은 분들께서 이해해 주시고 이쁘게 봐주셔서 \n감사합니다\n\n올 한 해 정말 고생 많으셨습니다\n남은 준공까지 더 열심히 하는 \n막내가 되겠습니다😊',
#   '154',
#   '41',
#   ''],
#  ['402',
#   '352-37-79694',
#   '2023-12-14 9:17',
#   '2023-12-14 9:31',
#   '[IMAGE] 수고했어요',
#   '김승우 매니저',
#   '김승우',
#   '2301070',
#   '',
#   '국내현장',
#   '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   '서용하 책임매니저, 김동호 책임매니저, 이성옥 책임매니저, 최신희 매니저, 남궁혜린 매니저',
#   '남궁혜린',
#   'hrhr02',
#   '국내현장',
#   '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   '팀장님 그리고 책임님, 매니저님\n안녕하세요!\n\n신입사원으로 입사하여 현장에 부임한지 \n약 1년이라는 시간 동안 팀장님을 비롯하여 \n많은 분들께서 이해해 주시고 이쁘게 봐주셔서 \n감사합니다\n\n올 한 해 정말 고생 많으셨습니다\n남은 준공까지 더 열심히 하는 \n막내가 되겠습니다😊',
#   '154',
#   '41',
#   ''],
#  ['406',
#   '542-72-70977',
#   '2023-12-14 9:45',
#   '2023-12-14 9:48',
#   '[IMAGE] 힘내세요',
#   '정신영 매니저',
#   '정신영',
#   '2011494',
#   '',
#   '본사',
#   '스마트ICT팀 / 본사',
#   '오상진 매니저',
#   '오상진',
#   '2011503',
#   '본사',
#   '스마트ICT팀 / 본사',
#   '오상진 매니저님, 올 한해도 새로운 기술도 많이 공유해주고 좋은 조언도 많이 해줘서 참 감사하게 생각합니다!\n최근 다치셔서 맘이 좋지 않은데 꼭 쾌차해서 내년에도 좋은 모습으로 볼 수 있었으면 좋겠습니다! 따뜻한 연말보내세요=) 화이팅!',
#   '132',
#   '72',
#   ''],
#  ['410',
#   '781-95-77268',
#   '2023-12-14 9:46',
#   '2023-12-14 9:56',
#   '[IMAGE] 고마워요',
#   '임대은 책임',
#   '임대은',
#   '1000491',
#   '',
#   '본사',
#   '플랜트장치기계설계팀 / 미국 AACE FEED Project 서울사무소',
#   '정은정 매니저',
#   '정은정',
#   '2313528',
#   '본사',
#   '플랜트설계관리팀 / 태국 TUCF Project 서울사무소',
#   'VDC 업무를 잘 해 주셔서 고마웠습니다. TUCF 거쳐간 VDC 중 최고',
#   '41',
#   '383',
#   ''],
#  ['447',
#   '530-30-94050',
#   '2023-12-14 11:16',
#   '2023-12-14 11:23',
#   '[IMAGE] 고마워요',
#   '이상원 책임매니저',
#   '이상원',
#   '1345045',
#   '',
#   '국내현장',
#   '건축수행팀/영남권모비스물류센터',
#   '김기오 팀장',
#   '김기오',
#   '0548595',
#   '본사',
#   '건축디자인실/building design',
#   '23년도\n영남권모비스현장에대한적극적인설계협조감사드립니다.발주처 직발설계로인해\n업무진행하는데어려움이많았는데\n팀장님 이하직원들의적극적인협조로인해 원활하게진행되고있습니딘\n다시한번감사드립니다',
#   '102',
#   '128',
#   '']]

# %%
headers_origin = allDatas[3]
list(enumerate(headers_origin))
# Out:
# [(0, '응답자ID'),
#  (1, '답변 확인 고유번호'),
#  (2, '시작일시'),
#  (3, '종료일시'),
#  (4, '어떤 마음을 전달해드릴까요? 카드를 선택하세요.'),
#  (5, '본인의 성명과 직급을 작성해주세요.'),
#  (6, '발신자 이름'),
#  (7, '발신자 사번'),
#  (8, ''),
#  (9, '현재 근무지를 입력해주세요.'),
#  (10, '현재 소속 팀과 근무지를 입력해주세요.'),
#  (11, '수신인의 성명과 직급을 작성해주세요.'),
#  (12, '수신자 이름'),
#  (13, '수신자 사번'),
#  (14, '수신인의 현재 근무지를 입력해주세요.'),
#  (15, '수신인이 속한 팀과 근무지를 입력해주세요.'),
#  (16, '전달하고 싶은 메시지 (고마워요 / 힘내세요 / 수고했어요)'),
#  (17, '글자수'),
#  (18, '글자수 순위'),
#  (19, '픽')]

# %%
keyInform = [
    [0, 'ID'],
    [2, 'start'],
    [4, 'message_type'],
    [5, 'sender_name_position'],
    [6, 'sender_name'],
    [7, 'sender_companyID'],
    [9, 'sender_work_place'],
    [10,'sender_department'],
    [11,'receiver_name_position'],
    [12,'receiver_name'],
    [13,'receiver_companyID'],
    [14,'receiver_work_place'],
    [15,'receiver_department'],
    [16,'message_content'],
]

# %%
allDatas_net = allDatas[5:]

# %%
def make_messageDict(oneRow, keyInform):
    keys = list(map(lambda x: x[1], keyInform))
    vals = list(map(lambda x: oneRow[x[0]], keyInform))
    
    return dict(zip(keys,vals))

make_messageDict(allDatas_net[0], keyInform)
# Out:
# {'ID': '16',
#  'start': '2023-12-05 7:48',
#  'message_type': '[IMAGE] 고마워요',
#  'sender_name_position': '최유리 매니저',
#  'sender_name': '최유리',
#  'sender_companyID': '2327330',
#  'sender_work_place': '서울사무소',
#  'sender_department': '사우디아미랄프로젝트',
#  'receiver_name_position': '김태권 매니저',
#  'receiver_name': '김태권',
#  'receiver_companyID': '2121246',
#  'receiver_work_place': '본사',
#  'receiver_department': '재무관리실 / 회계팀',
#  'message_content': '항상 친절하게 알려줘서 고마워요👍'}

# %%
allMsgDicts = list(map(lambda x: make_messageDict(x, keyInform), allDatas_net))
allMsgDicts
# Out:
# [{'ID': '16',
#   'start': '2023-12-05 7:48',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '최유리 매니저',
#   'sender_name': '최유리',
#   'sender_companyID': '2327330',
#   'sender_work_place': '서울사무소',
#   'sender_department': '사우디아미랄프로젝트',
#   'receiver_name_position': '김태권 매니저',
#   'receiver_name': '김태권',
#   'receiver_companyID': '2121246',
#   'receiver_work_place': '본사',
#   'receiver_department': '재무관리실 / 회계팀',
#   'message_content': '항상 친절하게 알려줘서 고마워요👍'},
#  {'ID': '22',
#   'start': '2023-12-05 8:24',
#   'message_type': '[IMAGE] 수고했어요',
#   'sender_name_position': '최선애 매니저',
#   'sender_name': '최선애',
#   'sender_companyID': '2212510',
#   'sender_work_place': '본사',
#   'sender_department': 'P2E팀',
#   'receiver_name_position': '이동희 책임매니저',
#   'receiver_name': '이동희',
#   'receiver_companyID': '2205126',
#   'receiver_work_place': '국내현장',
#   'receiver_department': '플랜트 수행실 사우디 SACE2 프로젝트',
#   'message_content': '책임님! 공인중개사 시험 준비할 때 응원해주셔서 감사합니다!! 그 응원덕에 붙을 수 있었습니다!! 내년엔 책임님도 공인중개사 합격!!입니다!!'},
#  {'ID': '28',
#   'start': '2023-12-05 17:33',
#   'message_type': '[IMAGE] 힘내세요',
#   'sender_name_position': '신민재 매니저',
#   'sender_name': '신민재',
#   'sender_companyID': '1600925',
#   'sender_work_place': '본사',
#   'sender_department': '건축전기팀 / 본사',
#   'receiver_name_position': '조성은 매니저',
#   'receiver_name': '조성은',
#   'receiver_companyID': '1923083',
#   'receiver_work_place': '본사',
#   'receiver_department': '건축전기팀 / 본사',
#   'message_content': 'NLB & 설계업무 병행하기 힘들었을텐데, 올 한해 고생많았습니다.\n업무에 열정적인 모습이 보기좋아요!\n내년에도 화이팅하자구요!!'},
#  {'ID': '48',
#   'start': '2023-12-06 7:51',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '김지훈 대리',
#   'sender_name': '김지훈',
#   'sender_companyID': '2101753',
#   'sender_work_place': '국내현장',
#   'sender_department': '자산현장1팀/현대차 동대구지점',
#   'receiver_name_position': '손병준 FM사업소장',
#   'receiver_name': '손병준',
#   'receiver_companyID': '1910165',
#   'receiver_work_place': '국내현장',
#   'receiver_department': '자산현장1팀/영남순회사무소',
#   'message_content': '소장님\n올 한해도 많은 도움과 협조\n감사합니다\n23년 마무리 잘하시고\n24년에도 힘내시고\n화이팅 ^~^'},
#  {'ID': '69',
#   'start': '2023-12-06 8:37',
#   'message_type': '[IMAGE] 수고했어요',
#   'sender_name_position': '이재학 매니저',
#   'sender_name': '이재학',
#   'sender_companyID': '1501872',
#   'sender_work_place': '해외현장',
#   'sender_department': '플랜트배관설계팀/인도네시아IKAN현장',
#   'receiver_name_position': '강창현 파트장',
#   'receiver_name': '강창현',
#   'receiver_companyID': '1595395',
#   'receiver_work_place': '해외현장',
#   'receiver_department': '플랜트배관설계팀/인도네시아IKAN현장',
#   'message_content': '하루하루 바쁜 현장에서, 후배 사원들을 따듯하게 챙겨주셔서 감사합니다!\n올 한해도 고생 많으셨습니다~'},
#  {'ID': '72',
#   'start': '2023-12-06 8:46',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '최한비 매니저',
#   'sender_name': '최한비',
#   'sender_companyID': '2318236',
#   'sender_work_place': '국내현장',
#   'sender_department': 'Building Design팀/광명기아현장',
#   'receiver_name_position': '김래영 매니저',
#   'receiver_name': '김래영',
#   'receiver_companyID': '2216615',
#   'receiver_work_place': '국내현장',
#   'receiver_department': 'Building Design팀/광명기아현장',
#   'message_content': '래용 매니저님~! 행복하고 배부른 연말을 보내요 우리,,'},
#  {'ID': '79',
#   'start': '2023-12-06 8:53',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '이상훈 책임매니저',
#   'sender_name': '이상훈',
#   'sender_companyID': '1501771',
#   'sender_work_place': '본사',
#   'sender_department': '플랜트설계관리팀 / 본사',
#   'receiver_name_position': '이재민 책임매니저',
#   'receiver_name': '이재민',
#   'receiver_companyID': '1439030',
#   'receiver_work_place': '본사',
#   'receiver_department': '플랜트설계관리팀 / 본사',
#   'message_content': '2023년 한해 수고 많으셨습니다. 감사합니다.'},
#  {'ID': '80',
#   'start': '2023-12-06 8:53',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '이상훈 책임매니저',
#   'sender_name': '이상훈',
#   'sender_companyID': '1501771',
#   'sender_work_place': '본사',
#   'sender_department': '플랜트설계관리팀 / 본사',
#   'receiver_name_position': '전미영 매니저',
#   'receiver_name': '전미영',
#   'receiver_companyID': '2222035',
#   'receiver_work_place': '본사',
#   'receiver_department': '플랜트설계관리팀 / 본사',
#   'message_content': '2023년 한해 수고 많으셨습니다. 감사합니다.'},
#  {'ID': '83',
#   'start': '2023-12-06 8:55',
#   'message_type': '[IMAGE] 힘내세요',
#   'sender_name_position': '이상훈 책임매니저',
#   'sender_name': '이상훈',
#   'sender_companyID': '1501771',
#   'sender_work_place': '본사',
#   'sender_department': '플랜트설계관리팀 / 본사',
#   'receiver_name_position': '강혜진 책임매니저',
#   'receiver_name': '강혜진',
#   'receiver_companyID': '0704536',
#   'receiver_work_place': '본사',
#   'receiver_department': 'GEC설립추진TFT / 본사',
#   'message_content': '2023년 한해 수고 많으셨습니다. 감사합니다.'},
#  {'ID': '84',
#   'start': '2023-12-06 8:55',
#   'message_type': '[IMAGE] 힘내세요',
#   'sender_name_position': '이상훈 책임매니저',
#   'sender_name': '이상훈',
#   'sender_companyID': '1501771',
#   'sender_work_place': '본사',
#   'sender_department': '플랜트설계관리팀 / 본사',
#   'receiver_name_position': '강주은 매니저',
#   'receiver_name': '강주은',
#   'receiver_companyID': '1119596',
#   'receiver_work_place': '본사',
#   'receiver_department': '플랜트설계관리팀 / 본사',
#   'message_content': '2023년 한해 수고 많으셨습니다. 감사합니다.'},
#  {'ID': '87',
#   'start': '2023-12-06 8:41',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '이영섭 책임매니저',
#   'sender_name': '이영섭',
#   'sender_companyID': '1501813',
#   'sender_work_place': '본사',
#   'sender_department': '플랜트설계관리팀 / 본사',
#   'receiver_name_position': '이상훈 책임매니저',
#   'receiver_name': '이상훈',
#   'receiver_companyID': '1501771',
#   'receiver_work_place': '본사',
#   'receiver_department': '플랜트설계관리팀 / 본사',
#   'message_content': '항상 올바른 지도 편달에 감사드립니다! 충성 충성!!'},
#  {'ID': '91',
#   'start': '2023-12-06 8:57',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '이동길 FM과장',
#   'sender_name': '이동길',
#   'sender_companyID': '1505944',
#   'sender_work_place': '국내현장',
#   'sender_department': '자산현장1팀/HMC사상하이테크센터',
#   'receiver_name_position': '양정호 책임매니저',
#   'receiver_name': '양정호',
#   'receiver_companyID': '1400881',
#   'receiver_work_place': '본사',
#   'receiver_department': '자산안전팀',
#   'message_content': '올해도 수고 많으셨습니다~'},
#  {'ID': '92',
#   'start': '2023-12-06 8:59',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '한대희 매니저',
#   'sender_name': '한대희',
#   'sender_companyID': '9921149',
#   'sender_work_place': '본사',
#   'sender_department': '자산상품개발TFT',
#   'receiver_name_position': '윤주성 매니저',
#   'receiver_name': '윤주성',
#   'receiver_companyID': '1438163',
#   'receiver_work_place': '본사',
#   'receiver_department': '자산상품개발TFT',
#   'message_content': '우리 사수 매니저님!\n진심이 느껴지는 조언들 항상 감사합니다!!'},
#  {'ID': '104',
#   'start': '2023-12-06 9:06',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '이상훈 책임매니저',
#   'sender_name': '이상훈',
#   'sender_companyID': '1501771',
#   'sender_work_place': '본사',
#   'sender_department': '플랜트설계관리팀 / 본사',
#   'receiver_name_position': '송정은 매니저',
#   'receiver_name': '송정은',
#   'receiver_companyID': '1004892',
#   'receiver_work_place': '본사',
#   'receiver_department': '지속가능경영팀 / 본사',
#   'message_content': '2023년 한해 수고 많으셨습니다. 감사합니다.'},
#  {'ID': '138',
#   'start': '2023-12-06 9:19',
#   'message_type': '[IMAGE] 힘내세요',
#   'sender_name_position': '이상훈 책임매니저',
#   'sender_name': '이상훈',
#   'sender_companyID': '1501771',
#   'sender_work_place': '본사',
#   'sender_department': '플랜트설계관리팀 / 본사',
#   'receiver_name_position': '장경선 책임매니저',
#   'receiver_name': '장경선',
#   'receiver_companyID': '1118121',
#   'receiver_work_place': '본사',
#   'receiver_department': '플랜트설계관리팀 / 본사',
#   'message_content': '2023년 한해 수고 많으셨습니다. 감사합니다.'},
#  {'ID': '148',
#   'start': '2023-12-06 9:47',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '이동길 FM과장',
#   'sender_name': '이동길',
#   'sender_companyID': '1505944',
#   'sender_work_place': '국내현장',
#   'sender_department': '자산현장1팀/HMC사상하이테크',
#   'receiver_name_position': '김철민 책임매니저',
#   'receiver_name': '김철민',
#   'receiver_companyID': '1627433',
#   'receiver_work_place': '본사',
#   'receiver_department': '자산안전팀',
#   'message_content': '언제 열일 하시는 김책임님~\n행복한 연말 보내세요~'},
#  {'ID': '214',
#   'start': '2023-12-11 8:43',
#   'message_type': '[IMAGE] 힘내세요',
#   'sender_name_position': '윤성한 소장',
#   'sender_name': '윤성한',
#   'sender_companyID': '2025703',
#   'sender_work_place': '국내현장',
#   'sender_department': '자산현장3팀/ 트랜시스 화성구동연구소',
#   'receiver_name_position': '김기연 대리',
#   'receiver_name': '김기연',
#   'receiver_companyID': '2226596',
#   'receiver_work_place': '국내현장',
#   'receiver_department': '자산현장3팀 / 트랜시스 화성구동연구소',
#   'message_content': '경력 신입사원으로 입사해 화성구동연구소 \n현장으로 발령 받은지 엊그제 같은데 벌써 1년이 넘었네요. 45살이면 적은 나이도 아닌데 현장 \n막내로써 잡다한 업무처리와 긍정적인 마인드로 업무에 임해주고 있어 항상 감사합니다. \n얼마 남지않은 23년 마무리 잘하고 24년 진일보 할수있는 새해가 되도록 계획 잘 세우고 목표 달성 할수 있도록 서로 노력합시다. 화이팀~~^^'},
#  {'ID': '249',
#   'start': '2023-12-11 14:53',
#   'message_type': '[IMAGE] 수고했어요',
#   'sender_name_position': '강주은 매니저',
#   'sender_name': '강주은',
#   'sender_companyID': '1119596',
#   'sender_work_place': '본사',
#   'sender_department': '플랜트설계관리팀/본사',
#   'receiver_name_position': '손병규 팀장',
#   'receiver_name': '손병규',
#   'receiver_companyID': '9934299',
#   'receiver_work_place': '본사',
#   'receiver_department': '플랜트설계관리팀/본사',
#   'message_content': '손병규 팀장님\n늘 직원들을 배려하는 마음으로 부서 업무에 힘써 주셔서 감사합니다\n올 한해도 수고 많으셨습니다~!!'},
#  {'ID': '318',
#   'start': '2023-12-14 6:54',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '류한정 책임',
#   'sender_name': '류한정',
#   'sender_companyID': '1000592',
#   'sender_work_place': '본사',
#   'sender_department': '경영기획팀',
#   'receiver_name_position': '이희동 책임',
#   'receiver_name': '이희동',
#   'receiver_companyID': '0852163',
#   'receiver_work_place': '본사',
#   'receiver_department': '인력운영팀',
#   'message_content': '올 한해 바쁘신 와중에 많은 도움을 주셔서 감사합니다. 내년에도 잘 부탁드립니다.'},
#  {'ID': '402',
#   'start': '2023-12-14 9:17',
#   'message_type': '[IMAGE] 수고했어요',
#   'sender_name_position': '김승우 매니저',
#   'sender_name': '김승우',
#   'sender_companyID': '2301070',
#   'sender_work_place': '국내현장',
#   'sender_department': '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   'receiver_name_position': '서용하 책임매니저, 김동호 책임매니저, 이성옥 책임매니저, 최신희 매니저, 남궁혜린 매니저',
#   'receiver_name': '서용하',
#   'receiver_companyID': '2213136',
#   'receiver_work_place': '국내현장',
#   'receiver_department': '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   'message_content': '팀장님 그리고 책임님, 매니저님\n안녕하세요!\n\n신입사원으로 입사하여 현장에 부임한지 \n약 1년이라는 시간 동안 팀장님을 비롯하여 \n많은 분들께서 이해해 주시고 이쁘게 봐주셔서 \n감사합니다\n\n올 한 해 정말 고생 많으셨습니다\n남은 준공까지 더 열심히 하는 \n막내가 되겠습니다😊'},
#  {'ID': '402',
#   'start': '2023-12-14 9:17',
#   'message_type': '[IMAGE] 수고했어요',
#   'sender_name_position': '김승우 매니저',
#   'sender_name': '김승우',
#   'sender_companyID': '2301070',
#   'sender_work_place': '국내현장',
#   'sender_department': '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   'receiver_name_position': '서용하 책임매니저, 김동호 책임매니저, 이성옥 책임매니저, 최신희 매니저, 남궁혜린 매니저',
#   'receiver_name': '김동호',
#   'receiver_companyID': '2201675',
#   'receiver_work_place': '국내현장',
#   'receiver_department': '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   'message_content': '팀장님 그리고 책임님, 매니저님\n안녕하세요!\n\n신입사원으로 입사하여 현장에 부임한지 \n약 1년이라는 시간 동안 팀장님을 비롯하여 \n많은 분들께서 이해해 주시고 이쁘게 봐주셔서 \n감사합니다\n\n올 한 해 정말 고생 많으셨습니다\n남은 준공까지 더 열심히 하는 \n막내가 되겠습니다😊'},
#  {'ID': '402',
#   'start': '2023-12-14 9:17',
#   'message_type': '[IMAGE] 수고했어요',
#   'sender_name_position': '김승우 매니저',
#   'sender_name': '김승우',
#   'sender_companyID': '2301070',
#   'sender_work_place': '국내현장',
#   'sender_department': '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   'receiver_name_position': '서용하 책임매니저, 김동호 책임매니저, 이성옥 책임매니저, 최신희 매니저, 남궁혜린 매니저',
#   'receiver_name': '이성옥',
#   'receiver_companyID': '2310946',
#   'receiver_work_place': '국내현장',
#   'receiver_department': '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   'message_content': '팀장님 그리고 책임님, 매니저님\n안녕하세요!\n\n신입사원으로 입사하여 현장에 부임한지 \n약 1년이라는 시간 동안 팀장님을 비롯하여 \n많은 분들께서 이해해 주시고 이쁘게 봐주셔서 \n감사합니다\n\n올 한 해 정말 고생 많으셨습니다\n남은 준공까지 더 열심히 하는 \n막내가 되겠습니다😊'},
#  {'ID': '402',
#   'start': '2023-12-14 9:17',
#   'message_type': '[IMAGE] 수고했어요',
#   'sender_name_position': '김승우 매니저',
#   'sender_name': '김승우',
#   'sender_companyID': '2301070',
#   'sender_work_place': '국내현장',
#   'sender_department': '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   'receiver_name_position': '서용하 책임매니저, 김동호 책임매니저, 이성옥 책임매니저, 최신희 매니저, 남궁혜린 매니저',
#   'receiver_name': '최신희',
#   'receiver_companyID': '2213432',
#   'receiver_work_place': '국내현장',
#   'receiver_department': '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   'message_content': '팀장님 그리고 책임님, 매니저님\n안녕하세요!\n\n신입사원으로 입사하여 현장에 부임한지 \n약 1년이라는 시간 동안 팀장님을 비롯하여 \n많은 분들께서 이해해 주시고 이쁘게 봐주셔서 \n감사합니다\n\n올 한 해 정말 고생 많으셨습니다\n남은 준공까지 더 열심히 하는 \n막내가 되겠습니다😊'},
#  {'ID': '402',
#   'start': '2023-12-14 9:17',
#   'message_type': '[IMAGE] 수고했어요',
#   'sender_name_position': '김승우 매니저',
#   'sender_name': '김승우',
#   'sender_companyID': '2301070',
#   'sender_work_place': '국내현장',
#   'sender_department': '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   'receiver_name_position': '서용하 책임매니저, 김동호 책임매니저, 이성옥 책임매니저, 최신희 매니저, 남궁혜린 매니저',
#   'receiver_name': '남궁혜린',
#   'receiver_companyID': 'hrhr02',
#   'receiver_work_place': '국내현장',
#   'receiver_department': '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   'message_content': '팀장님 그리고 책임님, 매니저님\n안녕하세요!\n\n신입사원으로 입사하여 현장에 부임한지 \n약 1년이라는 시간 동안 팀장님을 비롯하여 \n많은 분들께서 이해해 주시고 이쁘게 봐주셔서 \n감사합니다\n\n올 한 해 정말 고생 많으셨습니다\n남은 준공까지 더 열심히 하는 \n막내가 되겠습니다😊'},
#  {'ID': '406',
#   'start': '2023-12-14 9:45',
#   'message_type': '[IMAGE] 힘내세요',
#   'sender_name_position': '정신영 매니저',
#   'sender_name': '정신영',
#   'sender_companyID': '2011494',
#   'sender_work_place': '본사',
#   'sender_department': '스마트ICT팀 / 본사',
#   'receiver_name_position': '오상진 매니저',
#   'receiver_name': '오상진',
#   'receiver_companyID': '2011503',
#   'receiver_work_place': '본사',
#   'receiver_department': '스마트ICT팀 / 본사',
#   'message_content': '오상진 매니저님, 올 한해도 새로운 기술도 많이 공유해주고 좋은 조언도 많이 해줘서 참 감사하게 생각합니다!\n최근 다치셔서 맘이 좋지 않은데 꼭 쾌차해서 내년에도 좋은 모습으로 볼 수 있었으면 좋겠습니다! 따뜻한 연말보내세요=) 화이팅!'},
#  {'ID': '410',
#   'start': '2023-12-14 9:46',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '임대은 책임',
#   'sender_name': '임대은',
#   'sender_companyID': '1000491',
#   'sender_work_place': '본사',
#   'sender_department': '플랜트장치기계설계팀 / 미국 AACE FEED Project 서울사무소',
#   'receiver_name_position': '정은정 매니저',
#   'receiver_name': '정은정',
#   'receiver_companyID': '2313528',
#   'receiver_work_place': '본사',
#   'receiver_department': '플랜트설계관리팀 / 태국 TUCF Project 서울사무소',
#   'message_content': 'VDC 업무를 잘 해 주셔서 고마웠습니다. TUCF 거쳐간 VDC 중 최고'},
#  {'ID': '447',
#   'start': '2023-12-14 11:16',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '이상원 책임매니저',
#   'sender_name': '이상원',
#   'sender_companyID': '1345045',
#   'sender_work_place': '국내현장',
#   'sender_department': '건축수행팀/영남권모비스물류센터',
#   'receiver_name_position': '김기오 팀장',
#   'receiver_name': '김기오',
#   'receiver_companyID': '0548595',
#   'receiver_work_place': '본사',
#   'receiver_department': '건축디자인실/building design',
#   'message_content': '23년도\n영남권모비스현장에대한적극적인설계협조감사드립니다.발주처 직발설계로인해\n업무진행하는데어려움이많았는데\n팀장님 이하직원들의적극적인협조로인해 원활하게진행되고있습니딘\n다시한번감사드립니다'}]

# %%
aa = list(filter(lambda x: x['sender_name']=='익명', allMsgDicts))[0]
# Out:
# IndexErrorTraceback (most recent call last)
# <ipython-input-161-0494c0675507> in <module>
# ----> 1 aa = list(filter(lambda x: x['sender_name']=='익명', allMsgDicts))[0]
#
# IndexError: list index out of range

# %%
def set_email_address(d):
    if d['sender_name'] == '익명' or d['sender_companyID'] == '#N/A':
        d['sender_email'] = ''
        d['receiver_email'] = d['receiver_companyID']+'@hec.co.kr'
    else:
        d['sender_email'] = d['sender_companyID']+'@hec.co.kr'
        d['receiver_email'] = d['receiver_companyID']+'@hec.co.kr'
        
    return d

# %%
set_email_address(aa)
# Out:
# {'ID': '49',
#  'start': '2023-12-06 7:49',
#  'message_type': '[IMAGE] 수고했어요',
#  'sender_name_position': '익명 발신자',
#  'sender_name': '익명',
#  'sender_companyID': '#N/A',
#  'sender_work_place': '본사',
#  'sender_department': '플랜트HVAC설계팀 / 본사',
#  'receiver_name_position': '김상현 팀장',
#  'receiver_name': '김상현',
#  'receiver_companyID': '2300394',
#  'receiver_work_place': '본사',
#  'receiver_department': '플랜트HVAC설계팀 / 본사',
#  'message_content': '늘 팀을 위해 애써주시는 모습 감사드립니다. 너무 팀과 팀원들만 생각하지마시고 가끔은 팀장님 개인을 위한 시간을 가지며 마음의 휴식을 취하시면 좋겠습니다. 행복한 연말되시고 새해 복 많이 받으세요.',
#  'sender_email': '',
#  'receiver_email': '2300394@hec.co.kr'}

# %%
allMsgDicts_fin = list(map(set_email_address, allMsgDicts))
allMsgDicts_fin
# Out:
# [{'ID': '16',
#   'start': '2023-12-05 7:48',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '최유리 매니저',
#   'sender_name': '최유리',
#   'sender_companyID': '2327330',
#   'sender_work_place': '서울사무소',
#   'sender_department': '사우디아미랄프로젝트',
#   'receiver_name_position': '김태권 매니저',
#   'receiver_name': '김태권',
#   'receiver_companyID': '2121246',
#   'receiver_work_place': '본사',
#   'receiver_department': '재무관리실 / 회계팀',
#   'message_content': '항상 친절하게 알려줘서 고마워요👍',
#   'sender_email': '2327330@hec.co.kr',
#   'receiver_email': '2121246@hec.co.kr'},
#  {'ID': '22',
#   'start': '2023-12-05 8:24',
#   'message_type': '[IMAGE] 수고했어요',
#   'sender_name_position': '최선애 매니저',
#   'sender_name': '최선애',
#   'sender_companyID': '2212510',
#   'sender_work_place': '본사',
#   'sender_department': 'P2E팀',
#   'receiver_name_position': '이동희 책임매니저',
#   'receiver_name': '이동희',
#   'receiver_companyID': '2205126',
#   'receiver_work_place': '국내현장',
#   'receiver_department': '플랜트 수행실 사우디 SACE2 프로젝트',
#   'message_content': '책임님! 공인중개사 시험 준비할 때 응원해주셔서 감사합니다!! 그 응원덕에 붙을 수 있었습니다!! 내년엔 책임님도 공인중개사 합격!!입니다!!',
#   'sender_email': '2212510@hec.co.kr',
#   'receiver_email': '2205126@hec.co.kr'},
#  {'ID': '28',
#   'start': '2023-12-05 17:33',
#   'message_type': '[IMAGE] 힘내세요',
#   'sender_name_position': '신민재 매니저',
#   'sender_name': '신민재',
#   'sender_companyID': '1600925',
#   'sender_work_place': '본사',
#   'sender_department': '건축전기팀 / 본사',
#   'receiver_name_position': '조성은 매니저',
#   'receiver_name': '조성은',
#   'receiver_companyID': '1923083',
#   'receiver_work_place': '본사',
#   'receiver_department': '건축전기팀 / 본사',
#   'message_content': 'NLB & 설계업무 병행하기 힘들었을텐데, 올 한해 고생많았습니다.\n업무에 열정적인 모습이 보기좋아요!\n내년에도 화이팅하자구요!!',
#   'sender_email': '1600925@hec.co.kr',
#   'receiver_email': '1923083@hec.co.kr'},
#  {'ID': '48',
#   'start': '2023-12-06 7:51',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '김지훈 대리',
#   'sender_name': '김지훈',
#   'sender_companyID': '2101753',
#   'sender_work_place': '국내현장',
#   'sender_department': '자산현장1팀/현대차 동대구지점',
#   'receiver_name_position': '손병준 FM사업소장',
#   'receiver_name': '손병준',
#   'receiver_companyID': '1910165',
#   'receiver_work_place': '국내현장',
#   'receiver_department': '자산현장1팀/영남순회사무소',
#   'message_content': '소장님\n올 한해도 많은 도움과 협조\n감사합니다\n23년 마무리 잘하시고\n24년에도 힘내시고\n화이팅 ^~^',
#   'sender_email': '2101753@hec.co.kr',
#   'receiver_email': '1910165@hec.co.kr'},
#  {'ID': '69',
#   'start': '2023-12-06 8:37',
#   'message_type': '[IMAGE] 수고했어요',
#   'sender_name_position': '이재학 매니저',
#   'sender_name': '이재학',
#   'sender_companyID': '1501872',
#   'sender_work_place': '해외현장',
#   'sender_department': '플랜트배관설계팀/인도네시아IKAN현장',
#   'receiver_name_position': '강창현 파트장',
#   'receiver_name': '강창현',
#   'receiver_companyID': '1595395',
#   'receiver_work_place': '해외현장',
#   'receiver_department': '플랜트배관설계팀/인도네시아IKAN현장',
#   'message_content': '하루하루 바쁜 현장에서, 후배 사원들을 따듯하게 챙겨주셔서 감사합니다!\n올 한해도 고생 많으셨습니다~',
#   'sender_email': '1501872@hec.co.kr',
#   'receiver_email': '1595395@hec.co.kr'},
#  {'ID': '72',
#   'start': '2023-12-06 8:46',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '최한비 매니저',
#   'sender_name': '최한비',
#   'sender_companyID': '2318236',
#   'sender_work_place': '국내현장',
#   'sender_department': 'Building Design팀/광명기아현장',
#   'receiver_name_position': '김래영 매니저',
#   'receiver_name': '김래영',
#   'receiver_companyID': '2216615',
#   'receiver_work_place': '국내현장',
#   'receiver_department': 'Building Design팀/광명기아현장',
#   'message_content': '래용 매니저님~! 행복하고 배부른 연말을 보내요 우리,,',
#   'sender_email': '2318236@hec.co.kr',
#   'receiver_email': '2216615@hec.co.kr'},
#  {'ID': '79',
#   'start': '2023-12-06 8:53',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '이상훈 책임매니저',
#   'sender_name': '이상훈',
#   'sender_companyID': '1501771',
#   'sender_work_place': '본사',
#   'sender_department': '플랜트설계관리팀 / 본사',
#   'receiver_name_position': '이재민 책임매니저',
#   'receiver_name': '이재민',
#   'receiver_companyID': '1439030',
#   'receiver_work_place': '본사',
#   'receiver_department': '플랜트설계관리팀 / 본사',
#   'message_content': '2023년 한해 수고 많으셨습니다. 감사합니다.',
#   'sender_email': '1501771@hec.co.kr',
#   'receiver_email': '1439030@hec.co.kr'},
#  {'ID': '80',
#   'start': '2023-12-06 8:53',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '이상훈 책임매니저',
#   'sender_name': '이상훈',
#   'sender_companyID': '1501771',
#   'sender_work_place': '본사',
#   'sender_department': '플랜트설계관리팀 / 본사',
#   'receiver_name_position': '전미영 매니저',
#   'receiver_name': '전미영',
#   'receiver_companyID': '2222035',
#   'receiver_work_place': '본사',
#   'receiver_department': '플랜트설계관리팀 / 본사',
#   'message_content': '2023년 한해 수고 많으셨습니다. 감사합니다.',
#   'sender_email': '1501771@hec.co.kr',
#   'receiver_email': '2222035@hec.co.kr'},
#  {'ID': '83',
#   'start': '2023-12-06 8:55',
#   'message_type': '[IMAGE] 힘내세요',
#   'sender_name_position': '이상훈 책임매니저',
#   'sender_name': '이상훈',
#   'sender_companyID': '1501771',
#   'sender_work_place': '본사',
#   'sender_department': '플랜트설계관리팀 / 본사',
#   'receiver_name_position': '강혜진 책임매니저',
#   'receiver_name': '강혜진',
#   'receiver_companyID': '0704536',
#   'receiver_work_place': '본사',
#   'receiver_department': 'GEC설립추진TFT / 본사',
#   'message_content': '2023년 한해 수고 많으셨습니다. 감사합니다.',
#   'sender_email': '1501771@hec.co.kr',
#   'receiver_email': '0704536@hec.co.kr'},
#  {'ID': '84',
#   'start': '2023-12-06 8:55',
#   'message_type': '[IMAGE] 힘내세요',
#   'sender_name_position': '이상훈 책임매니저',
#   'sender_name': '이상훈',
#   'sender_companyID': '1501771',
#   'sender_work_place': '본사',
#   'sender_department': '플랜트설계관리팀 / 본사',
#   'receiver_name_position': '강주은 매니저',
#   'receiver_name': '강주은',
#   'receiver_companyID': '1119596',
#   'receiver_work_place': '본사',
#   'receiver_department': '플랜트설계관리팀 / 본사',
#   'message_content': '2023년 한해 수고 많으셨습니다. 감사합니다.',
#   'sender_email': '1501771@hec.co.kr',
#   'receiver_email': '1119596@hec.co.kr'},
#  {'ID': '87',
#   'start': '2023-12-06 8:41',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '이영섭 책임매니저',
#   'sender_name': '이영섭',
#   'sender_companyID': '1501813',
#   'sender_work_place': '본사',
#   'sender_department': '플랜트설계관리팀 / 본사',
#   'receiver_name_position': '이상훈 책임매니저',
#   'receiver_name': '이상훈',
#   'receiver_companyID': '1501771',
#   'receiver_work_place': '본사',
#   'receiver_department': '플랜트설계관리팀 / 본사',
#   'message_content': '항상 올바른 지도 편달에 감사드립니다! 충성 충성!!',
#   'sender_email': '1501813@hec.co.kr',
#   'receiver_email': '1501771@hec.co.kr'},
#  {'ID': '91',
#   'start': '2023-12-06 8:57',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '이동길 FM과장',
#   'sender_name': '이동길',
#   'sender_companyID': '1505944',
#   'sender_work_place': '국내현장',
#   'sender_department': '자산현장1팀/HMC사상하이테크센터',
#   'receiver_name_position': '양정호 책임매니저',
#   'receiver_name': '양정호',
#   'receiver_companyID': '1400881',
#   'receiver_work_place': '본사',
#   'receiver_department': '자산안전팀',
#   'message_content': '올해도 수고 많으셨습니다~',
#   'sender_email': '1505944@hec.co.kr',
#   'receiver_email': '1400881@hec.co.kr'},
#  {'ID': '92',
#   'start': '2023-12-06 8:59',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '한대희 매니저',
#   'sender_name': '한대희',
#   'sender_companyID': '9921149',
#   'sender_work_place': '본사',
#   'sender_department': '자산상품개발TFT',
#   'receiver_name_position': '윤주성 매니저',
#   'receiver_name': '윤주성',
#   'receiver_companyID': '1438163',
#   'receiver_work_place': '본사',
#   'receiver_department': '자산상품개발TFT',
#   'message_content': '우리 사수 매니저님!\n진심이 느껴지는 조언들 항상 감사합니다!!',
#   'sender_email': '9921149@hec.co.kr',
#   'receiver_email': '1438163@hec.co.kr'},
#  {'ID': '104',
#   'start': '2023-12-06 9:06',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '이상훈 책임매니저',
#   'sender_name': '이상훈',
#   'sender_companyID': '1501771',
#   'sender_work_place': '본사',
#   'sender_department': '플랜트설계관리팀 / 본사',
#   'receiver_name_position': '송정은 매니저',
#   'receiver_name': '송정은',
#   'receiver_companyID': '1004892',
#   'receiver_work_place': '본사',
#   'receiver_department': '지속가능경영팀 / 본사',
#   'message_content': '2023년 한해 수고 많으셨습니다. 감사합니다.',
#   'sender_email': '1501771@hec.co.kr',
#   'receiver_email': '1004892@hec.co.kr'},
#  {'ID': '138',
#   'start': '2023-12-06 9:19',
#   'message_type': '[IMAGE] 힘내세요',
#   'sender_name_position': '이상훈 책임매니저',
#   'sender_name': '이상훈',
#   'sender_companyID': '1501771',
#   'sender_work_place': '본사',
#   'sender_department': '플랜트설계관리팀 / 본사',
#   'receiver_name_position': '장경선 책임매니저',
#   'receiver_name': '장경선',
#   'receiver_companyID': '1118121',
#   'receiver_work_place': '본사',
#   'receiver_department': '플랜트설계관리팀 / 본사',
#   'message_content': '2023년 한해 수고 많으셨습니다. 감사합니다.',
#   'sender_email': '1501771@hec.co.kr',
#   'receiver_email': '1118121@hec.co.kr'},
#  {'ID': '148',
#   'start': '2023-12-06 9:47',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '이동길 FM과장',
#   'sender_name': '이동길',
#   'sender_companyID': '1505944',
#   'sender_work_place': '국내현장',
#   'sender_department': '자산현장1팀/HMC사상하이테크',
#   'receiver_name_position': '김철민 책임매니저',
#   'receiver_name': '김철민',
#   'receiver_companyID': '1627433',
#   'receiver_work_place': '본사',
#   'receiver_department': '자산안전팀',
#   'message_content': '언제 열일 하시는 김책임님~\n행복한 연말 보내세요~',
#   'sender_email': '1505944@hec.co.kr',
#   'receiver_email': '1627433@hec.co.kr'},
#  {'ID': '214',
#   'start': '2023-12-11 8:43',
#   'message_type': '[IMAGE] 힘내세요',
#   'sender_name_position': '윤성한 소장',
#   'sender_name': '윤성한',
#   'sender_companyID': '2025703',
#   'sender_work_place': '국내현장',
#   'sender_department': '자산현장3팀/ 트랜시스 화성구동연구소',
#   'receiver_name_position': '김기연 대리',
#   'receiver_name': '김기연',
#   'receiver_companyID': '2226596',
#   'receiver_work_place': '국내현장',
#   'receiver_department': '자산현장3팀 / 트랜시스 화성구동연구소',
#   'message_content': '경력 신입사원으로 입사해 화성구동연구소 \n현장으로 발령 받은지 엊그제 같은데 벌써 1년이 넘었네요. 45살이면 적은 나이도 아닌데 현장 \n막내로써 잡다한 업무처리와 긍정적인 마인드로 업무에 임해주고 있어 항상 감사합니다. \n얼마 남지않은 23년 마무리 잘하고 24년 진일보 할수있는 새해가 되도록 계획 잘 세우고 목표 달성 할수 있도록 서로 노력합시다. 화이팀~~^^',
#   'sender_email': '2025703@hec.co.kr',
#   'receiver_email': '2226596@hec.co.kr'},
#  {'ID': '249',
#   'start': '2023-12-11 14:53',
#   'message_type': '[IMAGE] 수고했어요',
#   'sender_name_position': '강주은 매니저',
#   'sender_name': '강주은',
#   'sender_companyID': '1119596',
#   'sender_work_place': '본사',
#   'sender_department': '플랜트설계관리팀/본사',
#   'receiver_name_position': '손병규 팀장',
#   'receiver_name': '손병규',
#   'receiver_companyID': '9934299',
#   'receiver_work_place': '본사',
#   'receiver_department': '플랜트설계관리팀/본사',
#   'message_content': '손병규 팀장님\n늘 직원들을 배려하는 마음으로 부서 업무에 힘써 주셔서 감사합니다\n올 한해도 수고 많으셨습니다~!!',
#   'sender_email': '1119596@hec.co.kr',
#   'receiver_email': '9934299@hec.co.kr'},
#  {'ID': '318',
#   'start': '2023-12-14 6:54',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '류한정 책임',
#   'sender_name': '류한정',
#   'sender_companyID': '1000592',
#   'sender_work_place': '본사',
#   'sender_department': '경영기획팀',
#   'receiver_name_position': '이희동 책임',
#   'receiver_name': '이희동',
#   'receiver_companyID': '0852163',
#   'receiver_work_place': '본사',
#   'receiver_department': '인력운영팀',
#   'message_content': '올 한해 바쁘신 와중에 많은 도움을 주셔서 감사합니다. 내년에도 잘 부탁드립니다.',
#   'sender_email': '1000592@hec.co.kr',
#   'receiver_email': '0852163@hec.co.kr'},
#  {'ID': '402',
#   'start': '2023-12-14 9:17',
#   'message_type': '[IMAGE] 수고했어요',
#   'sender_name_position': '김승우 매니저',
#   'sender_name': '김승우',
#   'sender_companyID': '2301070',
#   'sender_work_place': '국내현장',
#   'sender_department': '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   'receiver_name_position': '서용하 책임매니저, 김동호 책임매니저, 이성옥 책임매니저, 최신희 매니저, 남궁혜린 매니저',
#   'receiver_name': '서용하',
#   'receiver_companyID': '2213136',
#   'receiver_work_place': '국내현장',
#   'receiver_department': '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   'message_content': '팀장님 그리고 책임님, 매니저님\n안녕하세요!\n\n신입사원으로 입사하여 현장에 부임한지 \n약 1년이라는 시간 동안 팀장님을 비롯하여 \n많은 분들께서 이해해 주시고 이쁘게 봐주셔서 \n감사합니다\n\n올 한 해 정말 고생 많으셨습니다\n남은 준공까지 더 열심히 하는 \n막내가 되겠습니다😊',
#   'sender_email': '2301070@hec.co.kr',
#   'receiver_email': '2213136@hec.co.kr'},
#  {'ID': '402',
#   'start': '2023-12-14 9:17',
#   'message_type': '[IMAGE] 수고했어요',
#   'sender_name_position': '김승우 매니저',
#   'sender_name': '김승우',
#   'sender_companyID': '2301070',
#   'sender_work_place': '국내현장',
#   'sender_department': '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   'receiver_name_position': '서용하 책임매니저, 김동호 책임매니저, 이성옥 책임매니저, 최신희 매니저, 남궁혜린 매니저',
#   'receiver_name': '김동호',
#   'receiver_companyID': '2201675',
#   'receiver_work_place': '국내현장',
#   'receiver_department': '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   'message_content': '팀장님 그리고 책임님, 매니저님\n안녕하세요!\n\n신입사원으로 입사하여 현장에 부임한지 \n약 1년이라는 시간 동안 팀장님을 비롯하여 \n많은 분들께서 이해해 주시고 이쁘게 봐주셔서 \n감사합니다\n\n올 한 해 정말 고생 많으셨습니다\n남은 준공까지 더 열심히 하는 \n막내가 되겠습니다😊',
#   'sender_email': '2301070@hec.co.kr',
#   'receiver_email': '2201675@hec.co.kr'},
#  {'ID': '402',
#   'start': '2023-12-14 9:17',
#   'message_type': '[IMAGE] 수고했어요',
#   'sender_name_position': '김승우 매니저',
#   'sender_name': '김승우',
#   'sender_companyID': '2301070',
#   'sender_work_place': '국내현장',
#   'sender_department': '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   'receiver_name_position': '서용하 책임매니저, 김동호 책임매니저, 이성옥 책임매니저, 최신희 매니저, 남궁혜린 매니저',
#   'receiver_name': '이성옥',
#   'receiver_companyID': '2310946',
#   'receiver_work_place': '국내현장',
#   'receiver_department': '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   'message_content': '팀장님 그리고 책임님, 매니저님\n안녕하세요!\n\n신입사원으로 입사하여 현장에 부임한지 \n약 1년이라는 시간 동안 팀장님을 비롯하여 \n많은 분들께서 이해해 주시고 이쁘게 봐주셔서 \n감사합니다\n\n올 한 해 정말 고생 많으셨습니다\n남은 준공까지 더 열심히 하는 \n막내가 되겠습니다😊',
#   'sender_email': '2301070@hec.co.kr',
#   'receiver_email': '2310946@hec.co.kr'},
#  {'ID': '402',
#   'start': '2023-12-14 9:17',
#   'message_type': '[IMAGE] 수고했어요',
#   'sender_name_position': '김승우 매니저',
#   'sender_name': '김승우',
#   'sender_companyID': '2301070',
#   'sender_work_place': '국내현장',
#   'sender_department': '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   'receiver_name_position': '서용하 책임매니저, 김동호 책임매니저, 이성옥 책임매니저, 최신희 매니저, 남궁혜린 매니저',
#   'receiver_name': '최신희',
#   'receiver_companyID': '2213432',
#   'receiver_work_place': '국내현장',
#   'receiver_department': '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   'message_content': '팀장님 그리고 책임님, 매니저님\n안녕하세요!\n\n신입사원으로 입사하여 현장에 부임한지 \n약 1년이라는 시간 동안 팀장님을 비롯하여 \n많은 분들께서 이해해 주시고 이쁘게 봐주셔서 \n감사합니다\n\n올 한 해 정말 고생 많으셨습니다\n남은 준공까지 더 열심히 하는 \n막내가 되겠습니다😊',
#   'sender_email': '2301070@hec.co.kr',
#   'receiver_email': '2213432@hec.co.kr'},
#  {'ID': '402',
#   'start': '2023-12-14 9:17',
#   'message_type': '[IMAGE] 수고했어요',
#   'sender_name_position': '김승우 매니저',
#   'sender_name': '김승우',
#   'sender_companyID': '2301070',
#   'sender_work_place': '국내현장',
#   'sender_department': '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   'receiver_name_position': '서용하 책임매니저, 김동호 책임매니저, 이성옥 책임매니저, 최신희 매니저, 남궁혜린 매니저',
#   'receiver_name': '남궁혜린',
#   'receiver_companyID': 'hrhr02',
#   'receiver_work_place': '국내현장',
#   'receiver_department': '안전보건지원팀 / 힐스테이트 과천 디센트로 현장',
#   'message_content': '팀장님 그리고 책임님, 매니저님\n안녕하세요!\n\n신입사원으로 입사하여 현장에 부임한지 \n약 1년이라는 시간 동안 팀장님을 비롯하여 \n많은 분들께서 이해해 주시고 이쁘게 봐주셔서 \n감사합니다\n\n올 한 해 정말 고생 많으셨습니다\n남은 준공까지 더 열심히 하는 \n막내가 되겠습니다😊',
#   'sender_email': '2301070@hec.co.kr',
#   'receiver_email': 'hrhr02@hec.co.kr'},
#  {'ID': '406',
#   'start': '2023-12-14 9:45',
#   'message_type': '[IMAGE] 힘내세요',
#   'sender_name_position': '정신영 매니저',
#   'sender_name': '정신영',
#   'sender_companyID': '2011494',
#   'sender_work_place': '본사',
#   'sender_department': '스마트ICT팀 / 본사',
#   'receiver_name_position': '오상진 매니저',
#   'receiver_name': '오상진',
#   'receiver_companyID': '2011503',
#   'receiver_work_place': '본사',
#   'receiver_department': '스마트ICT팀 / 본사',
#   'message_content': '오상진 매니저님, 올 한해도 새로운 기술도 많이 공유해주고 좋은 조언도 많이 해줘서 참 감사하게 생각합니다!\n최근 다치셔서 맘이 좋지 않은데 꼭 쾌차해서 내년에도 좋은 모습으로 볼 수 있었으면 좋겠습니다! 따뜻한 연말보내세요=) 화이팅!',
#   'sender_email': '2011494@hec.co.kr',
#   'receiver_email': '2011503@hec.co.kr'},
#  {'ID': '410',
#   'start': '2023-12-14 9:46',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '임대은 책임',
#   'sender_name': '임대은',
#   'sender_companyID': '1000491',
#   'sender_work_place': '본사',
#   'sender_department': '플랜트장치기계설계팀 / 미국 AACE FEED Project 서울사무소',
#   'receiver_name_position': '정은정 매니저',
#   'receiver_name': '정은정',
#   'receiver_companyID': '2313528',
#   'receiver_work_place': '본사',
#   'receiver_department': '플랜트설계관리팀 / 태국 TUCF Project 서울사무소',
#   'message_content': 'VDC 업무를 잘 해 주셔서 고마웠습니다. TUCF 거쳐간 VDC 중 최고',
#   'sender_email': '1000491@hec.co.kr',
#   'receiver_email': '2313528@hec.co.kr'},
#  {'ID': '447',
#   'start': '2023-12-14 11:16',
#   'message_type': '[IMAGE] 고마워요',
#   'sender_name_position': '이상원 책임매니저',
#   'sender_name': '이상원',
#   'sender_companyID': '1345045',
#   'sender_work_place': '국내현장',
#   'sender_department': '건축수행팀/영남권모비스물류센터',
#   'receiver_name_position': '김기오 팀장',
#   'receiver_name': '김기오',
#   'receiver_companyID': '0548595',
#   'receiver_work_place': '본사',
#   'receiver_department': '건축디자인실/building design',
#   'message_content': '23년도\n영남권모비스현장에대한적극적인설계협조감사드립니다.발주처 직발설계로인해\n업무진행하는데어려움이많았는데\n팀장님 이하직원들의적극적인협조로인해 원활하게진행되고있습니딘\n다시한번감사드립니다',
#   'sender_email': '1345045@hec.co.kr',
#   'receiver_email': '0548595@hec.co.kr'}]

# %%
test_d = {'ID': '9',
  'start': '2023-12-01 16:36',
  'message_type': '[IMAGE] 수고했어요',
  'sender_name_position': '장만규 매니저',
  'sender_name': '장만규',
  'sender_companyID': '1600405',
  'sender_work_place': '본사',
  'sender_department': '플랜트건축설계팀 / 본사 4층',
  'receiver_name_position': '이호준 매니저',
  'receiver_name': '이호준',
  'receiver_companyID': '1900412',
  'receiver_work_place': '해외현장',
  'receiver_department': '안전보건협력팀',
  'message_content': '미국잘다녀와 ㅠㅠㅠㅠㅠ얼른 복귀해!!!',
  'sender_email': '1600405@hec.co.kr',
  'receiver_email': 'carpamea@naver.com'}

# %%
'수고했어요' in test_d['message_type']
# Out:
# True

# %%
보낸이 = "장만규 매니저"
받는이 = "김똑딱 책임매니저"
message_content = '책임님 그동안 품질경영팀에서 수고 많으셨고, 항상 도와주셔서 감사했습니다. \n새롭게 시작하는 현장 생활도 잘하실거라고 \n믿습니다. 항상 건강 잘챙기시고 화이팅하세요!'

# %%
# # https://ibb.co/LQyQxf9
# # https://ibb.co/wyMFNHW
# # https://ibb.co/VYSq1M9

# # 고마워요
# https://i.ibb.co/YBkLCfQ/img-thanks.jpg
# # 힘내세요
# https://i.ibb.co/mvKv97h/img-cheer.jpg 
# # 수고했어요
# https://i.ibb.co/rk4RGP6/img-goodjob.jpg

# %%
def set_mail_info(d):
    # (*)메일의 발신자 메일 주소, 수신자 메일 주소, 앱비밀번호(발신자)
    sender = 'nlb.thanks2@gmail.com'
    receiver = d['receiver_email']
    cc_users = [d['sender_email']]
#     bcc_users = []
    bcc_users = ['jangmankyu@hec.co.kr']#, 'yeji.luna@hec.co.kr', 'soungeun@hec.co.kr', 'ys.park@hec.co.kr']
    total_receiver = [receiver]+cc_users+bcc_users
    app_password = 'pnej lsfp wjsj dxxz' #'yice ygft mnhx nbtz'
    if '고마워요' in d['message_type']:
        img_src = 'https://i.ibb.co/YBkLCfQ/img-thanks.jpg'
    elif '힘내세요' in d['message_type']:
        img_src = 'https://i.ibb.co/mvKv97h/img-cheer.jpg'
    elif '수고했어요' in d['message_type']:
        img_src = 'https://i.ibb.co/rk4RGP6/img-goodjob.jpg'
    else:
        img_src = 'https://i.ibb.co/YBkLCfQ/img-thanks.jpg'
    
    보낸이 = d['sender_name_position']
    받는이 = d['receiver_name_position']
    message_content = d['message_content']
    
    # (*)보낼 메일의 내용과 제목
    content = f"""
    <!DOCTYPE html>
    <HTML>
    <HEAD>
    <TITLE>Top HTML Tags</TITLE>
    </HEAD>
    <link rel="preconnect" href="https://fonts.googleapis.com">
    <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>
    <link href="https://fonts.googleapis.com/css2?family=Nanum+Gothic:wght@400;700&display=swap" rel="stylesheet">
    <BODY>
    <p>2023년 협업 감사메시지 이벤트에 참여해주신 분들의 메세지를 전달드립니다!</p><br>
    <CENTER><IMG src={img_src}></CENTER><BR>
    <CENTER>
    <H2>From. {보낸이}<BR>
    To. {받는이}</H2><BR><BR>

    <H3 class ="RIDIBatang">{message_content}</H3></CENTER>
    <BR><BR><BR><BR><BR><P><CENTER>- 끝 -</CENTER></P>
    </BODY>
    </HTML>
    """
    title = f'NLB가 {받는이}님께 연말 감사메시지를 전달해 드립니다!'
    
    res = {
        'sender' : sender,
        'receiver' : receiver,
        'cc_users' : cc_users,
        'bcc_users' : bcc_users,
        'total_receiver' : total_receiver,
        'app_password' : app_password,
        'img_src' : img_src,
        '보낸이' : 보낸이,
        '받는이' : 받는이,
        'content' : content,
        'title' : title,
        'app_password' : app_password 
    }
    return res

set_mail_info(test_d)
# Out:
# {'sender': 'nlb.thanks2@gmail.com',
#  'receiver': 'carpamea@naver.com',
#  'cc_users': ['1600405@hec.co.kr'],
#  'bcc_users': ['jangmankyu@hec.co.kr'],
#  'total_receiver': ['carpamea@naver.com',
#   '1600405@hec.co.kr',
#   'jangmankyu@hec.co.kr'],
#  'app_password': 'pnej lsfp wjsj dxxz',
#  'img_src': 'https://i.ibb.co/rk4RGP6/img-goodjob.jpg',
#  '보낸이': '장만규 매니저',
#  '받는이': '이호준 매니저',
#  'content': '\n    <!DOCTYPE html>\n    <HTML>\n    <HEAD>\n    <TITLE>Top HTML Tags</TITLE>\n    </HEAD>\n    <link rel="preconnect" href="https://fonts.googleapis.com">\n    <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>\n    <link href="https://fonts.googleapis.com/css2?family=Nanum+Gothic:wght@400;700&display=swap" rel="stylesheet">\n    <BODY>\n    <p>2023년 협업 감사메시지 이벤트에 참여해주신 분들의 메세지를 전달드립니다!</p><br>\n    <CENTER><IMG src=https://i.ibb.co/rk4RGP6/img-goodjob.jpg></CENTER><BR>\n    <CENTER>\n    <H2>From. 장만규 매니저<BR>\n    To. 이호준 매니저</H2><BR><BR>\n\n    <H3 class ="RIDIBatang">미국잘다녀와 ㅠㅠㅠㅠㅠ얼른 복귀해!!!</H3></CENTER>\n    <BR><BR><BR><BR><BR><P><CENTER>- 끝 -</CENTER></P>\n    </BODY>\n    </HTML>\n    ',
#  'title': 'NLB가 이호준 매니저님께 연말 감사메시지를 전달해 드립니다!'}

# %%
def send_mail_toAddres(_d):
    d = set_mail_info(_d)
    title = d['title']
    sender = d['sender']
    receiver = d['receiver']
    cc_users = d['cc_users']
    bcc_users = d['bcc_users']
    total_receiver = d['total_receiver']
    content = d['content']
    app_password = d['app_password']
    
    msg = MIMEMultipart('alternative')
    msg['Subject'] = title
    msg['From'] = sender
    msg['To'] = receiver
    msg['Cc'] = ", ".join(cc_users)

    msg.attach(MIMEText(content,'html'))
    
    # 세션 생성
    with smtplib.SMTP('smtp.gmail.com', 587) as s:
    #with smtplib.SMTP_SSL('smtp.gmail.com', 587) as s:
        s.starttls()

    # 로그인 인증과 메일 보내기
        s.login(sender, app_password)  
        s.sendmail(sender, total_receiver, msg.as_string())
    
    print(f"{cc_users} to {receiver} sending success!")

# %%
test_samples = [test_d]

# %%
list(map(send_mail_toAddres, allMsgDicts_fin))
# Out:
# ['2327330@hec.co.kr'] to 2121246@hec.co.kr sending success!
# ['2212510@hec.co.kr'] to 2205126@hec.co.kr sending success!
# ['1600925@hec.co.kr'] to 1923083@hec.co.kr sending success!
# ['2101753@hec.co.kr'] to 1910165@hec.co.kr sending success!
# ['1501872@hec.co.kr'] to 1595395@hec.co.kr sending success!
# ['2318236@hec.co.kr'] to 2216615@hec.co.kr sending success!
# ['1501771@hec.co.kr'] to 1439030@hec.co.kr sending success!
# ['1501771@hec.co.kr'] to 2222035@hec.co.kr sending success!
# ['1501771@hec.co.kr'] to 0704536@hec.co.kr sending success!
# ['1501771@hec.co.kr'] to 1119596@hec.co.kr sending success!
# ['1501813@hec.co.kr'] to 1501771@hec.co.kr sending success!
# ['1505944@hec.co.kr'] to 1400881@hec.co.kr sending success!
# ['9921149@hec.co.kr'] to 1438163@hec.co.kr sending success!
# ['1501771@hec.co.kr'] to 1004892@hec.co.kr sending success!
# ['1501771@hec.co.kr'] to 1118121@hec.co.kr sending success!
# ['1505944@hec.co.kr'] to 1627433@hec.co.kr sending success!
# ['2025703@hec.co.kr'] to 2226596@hec.co.kr sending success!
# ['1119596@hec.co.kr'] to 9934299@hec.co.kr sending success!
# ['1000592@hec.co.kr'] to 0852163@hec.co.kr sending success!
# ['2301070@hec.co.kr'] to 2213136@hec.co.kr sending success!
# ['2301070@hec.co.kr'] to 2201675@hec.co.kr sending success!
# ['2301070@hec.co.kr'] to 2310946@hec.co.kr sending success!
# ['2301070@hec.co.kr'] to 2213432@hec.co.kr sending success!
# ['2301070@hec.co.kr'] to hrhr02@hec.co.kr sending success!
# ['2011494@hec.co.kr'] to 2011503@hec.co.kr sending success!
# ['1000491@hec.co.kr'] to 2313528@hec.co.kr sending success!
# ['1345045@hec.co.kr'] to 0548595@hec.co.kr sending success!
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
누락명단=[
    {'ID': '190',
  'start': '2023-12-07 15:58',
  'message_type': '[IMAGE] 고마워요',
  'sender_name_position': '바이톈휘 매니저',
  'sender_name': '바이톈휘',
  'sender_companyID': '2302045',
  'sender_work_place': '본사',
  'sender_department': '플랜트외주팀',
  'receiver_name_position': '조덕행 책임매니저',
  'receiver_name': '조덕행',
  'receiver_companyID': '--',
  'receiver_work_place': '본사',
  'receiver_department': '플랜트외주팀',
  'message_content': '고필성 책임님, 조덕행 책임님 : \n우선 책임님과 같이 일할 수 있어서 너무 좋습니다. 항상 친절하게 많이 가르쳐주셔서 너무너무 감사합니다. 덕분에 1년동안 많이 배울 수 있었습니다. 저도 열심히 공부해서 내년에 책임님들의 부담을 덜어줄 수 있도록 노력하겠습니다!\n항상 건강하시고 하시는 일이 잘 되기를 바랍니다!\n감사합니다.',
  'sender_email': '2302045@hec.co.kr',
  'receiver_email': 'dkcho@hec.co.kr'},
    {'ID': '167',
  'start': '2023-12-06 12:38',
  'message_type': '[IMAGE] 고마워요',
  'sender_name_position': '김민주 책임매니저',
  'sender_name': '김민주',
  'sender_companyID': '0900231',
  'sender_work_place': '본사',
  'sender_department': '인사기획팀',
  'receiver_name_position': '인사기획팀 all',
  'receiver_name': '인사기획팀',
  'receiver_companyID': '--',
  'receiver_work_place': '본사',
  'receiver_department': '인사기획팀',
  'message_content': '새로운 회사 적응에 어리버리했던 시절,\n먼저 말걸어주고, 함께 밥먹고, 업무 도와주신 팀원 분들 모두 감사합니다.\n내년엔 제가 더 많이 베풀고 비타민이 되어드리겠습니다.\n-비타민주 드림-',
  'sender_email': '2302045@hec.co.kr',
  'receiver_email': 'hrd@hec.co.kr'},
    
]

# %%
list(map(send_mail_toAddres, 누락명단))
# Out:
# ['2302045@hec.co.kr'] to dkcho@hec.co.kr sending success!
# ['2302045@hec.co.kr'] to hrd@hec.co.kr sending success!
# [None, None]
