# %%
import pandas as pd

# %%
df = pd.read_csv('거래내역.csv', encoding='cp949')

# %%
df
# Out:
#                                     카드번호(CARD_ID) 운행출발일시(START_DATETIME)  \
# 0    i*/*L*h*t*4*v*0*c*x*L*A*O*+*I*V*I*u*8*I*Z*0*         20180224104506
# 1    9*D*N*I*Y*A*8*9*c*5*E*u*E*T*C*U*+*G*q*9*J*I*         20170311161320
# 2    V*C*B*4*X*v*M*S*+*K*Z*w*+*N*5*0*h*0*i*F*E*M*                      ~
# 3    i*2*i*q*+*O*A*/*u*e*E*c*i*Q*R*5*O*2*u*T*M*c*                      ~
# 4    a*D*v*7*7*M*m*Y*3*I*f*3*G*U*a*/*7*T*b*z*a*k*         20170311035835
# ..                                            ...                    ...
# 495  B*8*2*y*4*1*T*6*J*b*7*/*P*1*r*m*K*4*C*A*Z*k*         20180824134928
# 496  C*G*I*8*M*L*K*t*u*W*O*x*/*X*K*m*1*J*n*R*4*0*                      ~
# 497  7*V*v*S*m*v*8*Y*B*M*F*8*/*4*7*V*D*X*s*2*e*8*         20191019141135
# 498  6*Y*i*9*f*4*k*v*3*W*c*2*A*f*G*1*4*I*0*W*c*A*                      ~
# 499  P*Z*L*t*x*g*X*E*m*j*Z*m*8*Q*2*G*Z*/*8*s*m*0*                      ~
#
#      트랜잭션ID(TRANSACTION_ID)  교통수단CD(SUDAN_CD)  환승횟수(TRANSFER_CNT)  \
# ...

# %%
df.loc[67]
# Out:
# 카드번호(CARD_ID)                   k*Y*y*Z*N*H*g*g*T*D*Z*J*f*5*7*X*d*P*I*p*r*k*
# 운행출발일시(START_DATETIME)                                                     ~
# 트랜잭션ID(TRANSACTION_ID)                                                    60
# 교통수단CD(SUDAN_CD)                                                         203
# 환승횟수(TRANSFER_CNT)                                                         1
# 버스노선ID(LINE_ID)                                                     11110269
# 교통사업자ID(COMPANY_ID)                                                211000000
# 차량ID(VEHICLE_ID)                                                           ~
# 교통카드발행사ID(CARD_COMP_ID)                                              2001400
# 교통카드사용자구분코드(CARD_USER_GBN)                                                 1
# 교통카드사용자구분코드1(BILL_USER_GBN1)                                               6
# 교통카드사용자구분코드2(BILL_USER_GBN2)                                               ~
# ...

# %%
df.loc[67:69]
# Out:
#                                    카드번호(CARD_ID) 운행출발일시(START_DATETIME)  \
# 67  k*Y*y*Z*N*H*g*g*T*D*Z*J*f*5*7*X*d*P*I*p*r*k*                      ~
# 68  G*t*w*W*L*q*n*X*A*2*s*T*Z*i*V*V*h*3*c*q*i*s*         20191221183009
# 69  S*9*y*+*e*Z*/*r*g*K*S*t*e*b*1*p*J*n*t*S*q*4*                      ~
#
#     트랜잭션ID(TRANSACTION_ID)  교통수단CD(SUDAN_CD)  환승횟수(TRANSFER_CNT)  \
# 67                      60               203                   1
# 68                      60               201                   0
# 69                      79               115                   2
#
#    버스노선ID(LINE_ID)  교통사업자ID(COMPANY_ID) 차량ID(VEHICLE_ID)  \
# 67        11110269            211000000                ~
# 68               ~            211000000        111706337
# 69               ~            111004500        111744337
#
#     교통카드발행사ID(CARD_COMP_ID)  교통카드사용자구분코드(CARD_USER_GBN)  ...  \
# 67                  2001400                           1  ...
# ...

# %%
df.columns
# Out:
# Index(['카드번호(CARD_ID)', '운행출발일시(START_DATETIME)', '트랜잭션ID(TRANSACTION_ID)',
#        '교통수단CD(SUDAN_CD)', '환승횟수(TRANSFER_CNT)', '버스노선ID(LINE_ID)',
#        '교통사업자ID(COMPANY_ID)', '차량ID(VEHICLE_ID)', '교통카드발행사ID(CARD_COMP_ID)',
#        '교통카드사용자구분코드(CARD_USER_GBN)', '교통카드사용자구분코드1(BILL_USER_GBN1)',
#        '교통카드사용자구분코드2(BILL_USER_GBN2)', '교통카드사용자구분코드3(BILL_USER_GBN3)',
#        '승차일시(GETON_DATETIME)', '승차정류장ID(GETON_STATION_ID)',
#        '하차일시(GETOFF_DATETIME)', '하차정류장ID(GETOFF_STATION_ID)',
#        '승객수1(PASSN_CNT1)', '승객수2(PASSN_CNT2)', '승객수3(PASSN_CNT3)',
#        '이용거리(MOV_DIST)'],
#       dtype='object')

# %%
df['교통수단CD(SUDAN_CD)']
# Out:
# 0      120
# 1      120
# 2      105
# 3      203
# 4      203
#       ...
# 495    201
# 496    203
# 497    201
# 498    120
# 499    201
# Name: 교통수단CD(SUDAN_CD), Length: 500, dtype: int64

# %%
코드 = pd.read_csv('코드.csv', encoding='cp949')

# %%
코드
# Out:
#      코드구분(GBN_CD) 코드구분명(GBN_NM) 코드값(CODE) 코드명(CODE_NM)
# 0               1        교통수단코드       105    마을버스(105)
# 1               1        교통수단코드       115         간선버스
# 2               1        교통수단코드       120    지선버스(120)
# 3               1        교통수단코드       121    지선버스(121)
# 4               1        교통수단코드       130    광역버스(130)
# ..            ...           ...       ...          ...
# 499             4    1회권사용자구분코드        44       영어 어린이
# 500             4    1회권사용자구분코드        45       일어 어린이
# 501             4    1회권사용자구분코드        46      중국어 어린이
# 502             5      1회권발행사ID   C900001       코레일1회권
# 503             5      1회권발행사ID   C900008          티머니
#
# [504 rows x 4 columns]

# %%
교통수단코드 = 코드.loc[(코드['코드구분명(GBN_NM)'] == '교통수단코드'), :]

# %%
교통수단코드
# Out:
#     코드구분(GBN_CD) 코드구분명(GBN_NM) 코드값(CODE)              코드명(CODE_NM)
# 0              1        교통수단코드       105                 마을버스(105)
# 1              1        교통수단코드       115                      간선버스
# 2              1        교통수단코드       120                 지선버스(120)
# 3              1        교통수단코드       121                 지선버스(121)
# 4              1        교통수단코드       130                 광역버스(130)
# 5              1        교통수단코드       131                 심야버스(131)
# 6              1        교통수단코드       140                      순환버스
# 7              1        교통수단코드       142                 도심순환(142)
# 8              1        교통수단코드       201                     서울메트로
# 9              1        교통수단코드       202                    한국철도공사
# 10             1        교통수단코드       203                  서울도시철도공사
# 11             1        교통수단코드       204                    인천교통공사
# 12             1        교통수단코드       205                       9호선
# ...

# %%
교통수단코드_정리 = 교통수단코드[['코드값(CODE)', '코드명(CODE_NM)']]

# %%
교통수단코드_정리
# Out:
#    코드값(CODE)              코드명(CODE_NM)
# 0        105                 마을버스(105)
# 1        115                      간선버스
# 2        120                 지선버스(120)
# 3        121                 지선버스(121)
# 4        130                 광역버스(130)
# 5        131                 심야버스(131)
# 6        140                      순환버스
# 7        142                 도심순환(142)
# 8        201                     서울메트로
# 9        202                    한국철도공사
# 10       203                  서울도시철도공사
# 11       204                    인천교통공사
# 12       205                       9호선
# 13       206                      공항철도
# 14       208                      신분당선
# 15       209                      경기철도
# 16       231                용인경량전철(통합)
# 17       232               의정부 경전철(통합)
# 18       235                   우이신설경전철
# 19       236                    김포도시철도
# 20       470                      인천간선
# 21       472          인천마을버스(472)-기본요금
# 22       475                    인천급행간선
# ...

# %%
교통수단코드_정리.set_index('코드값(CODE)').T
# Out:
# 코드값(CODE)           105   115        120        121        130        131  \
# 코드명(CODE_NM)  마을버스(105)  간선버스  지선버스(120)  지선버스(121)  광역버스(130)  심야버스(131)
#
# 코드값(CODE)      140        142    201     202  ...                511  \
# 코드명(CODE_NM)  순환버스  도심순환(142)  서울메트로  한국철도공사  ...  경기 일반버스(511)-기본요금
#
# 코드값(CODE)           530        533             550                       570  \
# 코드명(CODE_NM)  경기좌석(530)  경기좌석(533)  경기순환버스-초승거리비례제  국토부경기광역(570)-초승거리비례제-M버스
#
# 코드값(CODE)              580           581           582          583  \
# 코드명(CODE_NM)  경기 마을버스(580)  경기 마을버스(581)  경기 마을버스(582)  경기마을버스(583)
#
# 코드값(CODE)                  584
# 코드명(CODE_NM)  경기마을버스(584)-기본요금
#
# [1 rows x 42 columns]

# %%
코드맵 = 교통수단코드_정리.set_index('코드값(CODE)').T.to_dict('records')[0]

# %%
코드맵
# Out:
# {'105': '마을버스(105)',
#  '115': '간선버스',
#  '120': '지선버스(120)',
#  '121': '지선버스(121)',
#  '130': '광역버스(130)',
#  '131': '심야버스(131)',
#  '140': '순환버스',
#  '142': '도심순환(142)',
#  '201': '서울메트로',
#  '202': '한국철도공사',
#  '203': '서울도시철도공사',
#  '204': '인천교통공사',
#  '205': '9호선',
#  '206': '공항철도',
#  '208': '신분당선',
#  '209': '경기철도',
#  '231': '용인경량전철(통합)',
#  '232': '의정부 경전철(통합)',
#  '235': '우이신설경전철',
#  '236': '김포도시철도',
#  '470': '인천간선',
#  '472': '인천마을버스(472)-기본요금',
#  '475': '인천급행간선',
#  '476': '인천시내좌석',
#  '480': '인천지선',
#  '481': '인천마을버스',
#  '483': '인천공항좌석(483)-초승거리비례제',
#  '485': '인천광역버스(485)-초승거리비례제',
#  '487': '인천광역구버스',
#  '491': '인천좌석버스(491)-초승거리비례제',
#  '496': '국토부인천광역(496)-초승거리비례제-M버스',
#  '500': '경기일반버스(500)-초승거리비례제',
#  '511': '경기 일반버스(511)-기본요금',
#  '530': '경기좌석(530)',
#  '533': '경기좌석(533)',
#  '550': '경기순환버스-초승거리비례제',
#  '570': '국토부경기광역(570)-초승거리비례제-M버스',
#  '580': '경기 마을버스(580)',
#  '581': '경기 마을버스(581)',
#  '582': '경기 마을버스(582)',
#  '583': '경기마을버스(583)',
# ...

# %%
코드맵['105']
# Out:
# '마을버스(105)'

# %%
교통수단_numbers = df['교통수단CD(SUDAN_CD)'].to_list()

# %%
교통수단_numbers
# Out:
# [120,
#  120,
#  105,
#  203,
#  203,
#  105,
#  120,
#  115,
#  115,
#  120,
#  115,
#  201,
#  201,
#  201,
#  115,
#  201,
#  201,
#  105,
#  115,
#  201,
#  115,
#  115,
#  203,
#  201,
#  115,
#  203,
#  120,
#  115,
#  105,
#  115,
#  201,
#  115,
#  201,
#  120,
#  201,
#  203,
#  105,
#  203,
#  115,
#  120,
#  203,
#  201,
#  205,
#  105,
#  105,
#  201,
#  115,
#  115,
#  201,
#  201,
#  120,
#  201,
#  201,
#  120,
#  120,
#  203,
#  120,
#  115,
#  201,
#  120,
#  201,
#  120,
#  120,
#  201,
#  201,
#  201,
#  105,
#  203,
#  201,
#  115,
#  115,
#  201,
#  203,
#  120,
#  201,
#  120,
#  120,
#  120,
#  201,
#  105,
#  203,
#  120,
#  205,
#  105,
#  205,
#  203,
#  120,
#  201,
#  201,
#  105,
#  201,
#  120,
#  120,
#  120,
#  105,
#  120,
#  120,
#  105,
#  120,
#  203,
#  203,
#  201,
#  201,
#  105,
#  105,
#  201,
#  201,
#  120,
#  203,
#  115,
#  115,
#  120,
#  201,
#  120,
#  203,
#  115,
#  120,
#  203,
#  120,
#  115,
#  115,
#  115,
#  120,
#  115,
#  105,
# ...

# %%
new_values = list(map(lambda x: 코드맵[str(x)], 교통수단_numbers))

# %%
new_values = []
for x in 교통수단_numbers:
    new_values.append(코드맵[str(x)])

# %%
new_values
# Out:
# ['지선버스(120)',
#  '지선버스(120)',
#  '마을버스(105)',
#  '서울도시철도공사',
#  '서울도시철도공사',
#  '마을버스(105)',
#  '지선버스(120)',
#  '간선버스',
#  '간선버스',
#  '지선버스(120)',
#  '간선버스',
#  '서울메트로',
#  '서울메트로',
#  '서울메트로',
#  '간선버스',
#  '서울메트로',
#  '서울메트로',
#  '마을버스(105)',
#  '간선버스',
#  '서울메트로',
#  '간선버스',
#  '간선버스',
#  '서울도시철도공사',
#  '서울메트로',
#  '간선버스',
#  '서울도시철도공사',
#  '지선버스(120)',
#  '간선버스',
#  '마을버스(105)',
#  '간선버스',
#  '서울메트로',
#  '간선버스',
#  '서울메트로',
#  '지선버스(120)',
#  '서울메트로',
#  '서울도시철도공사',
#  '마을버스(105)',
#  '서울도시철도공사',
#  '간선버스',
#  '지선버스(120)',
#  '서울도시철도공사',
#  '서울메트로',
#  '9호선',
#  '마을버스(105)',
#  '마을버스(105)',
#  '서울메트로',
#  '간선버스',
#  '간선버스',
#  '서울메트로',
#  '서울메트로',
#  '지선버스(120)',
#  '서울메트로',
#  '서울메트로',
#  '지선버스(120)',
#  '지선버스(120)',
#  '서울도시철도공사',
#  '지선버스(120)',
#  '간선버스',
#  '서울메트로',
#  '지선버스(120)',
#  '서울메트로',
#  '지선버스(120)',
#  '지선버스(120)',
#  '서울메트로',
#  '서울메트로',
#  '서울메트로',
#  '마을버스(105)',
#  '서울도시철도공사',
#  '서울메트로',
#  '간선버스',
#  '간선버스',
#  '서울메트로',
#  '서울도시철도공사',
#  '지선버스(120)',
# ...

# %%
df.insert(4, "교통수단_이름", new_values)

# %%
df
# Out:
#                                     카드번호(CARD_ID) 운행출발일시(START_DATETIME)  \
# 0    i*/*L*h*t*4*v*0*c*x*L*A*O*+*I*V*I*u*8*I*Z*0*         20180224104506
# 1    9*D*N*I*Y*A*8*9*c*5*E*u*E*T*C*U*+*G*q*9*J*I*         20170311161320
# 2    V*C*B*4*X*v*M*S*+*K*Z*w*+*N*5*0*h*0*i*F*E*M*                      ~
# 3    i*2*i*q*+*O*A*/*u*e*E*c*i*Q*R*5*O*2*u*T*M*c*                      ~
# 4    a*D*v*7*7*M*m*Y*3*I*f*3*G*U*a*/*7*T*b*z*a*k*         20170311035835
# ..                                            ...                    ...
# 495  B*8*2*y*4*1*T*6*J*b*7*/*P*1*r*m*K*4*C*A*Z*k*         20180824134928
# 496  C*G*I*8*M*L*K*t*u*W*O*x*/*X*K*m*1*J*n*R*4*0*                      ~
# 497  7*V*v*S*m*v*8*Y*B*M*F*8*/*4*7*V*D*X*s*2*e*8*         20191019141135
# 498  6*Y*i*9*f*4*k*v*3*W*c*2*A*f*G*1*4*I*0*W*c*A*                      ~
# 499  P*Z*L*t*x*g*X*E*m*j*Z*m*8*Q*2*G*Z*/*8*s*m*0*                      ~
#
#      트랜잭션ID(TRANSACTION_ID)  교통수단CD(SUDAN_CD)    교통수단_이름  환승횟수(TRANSFER_CNT)  \
# ...

# %%
new_df = df[['카드번호(CARD_ID)', '운행출발일시(START_DATETIME)', '교통수단_이름']]

# %%
new_df
# Out:
#                                     카드번호(CARD_ID) 운행출발일시(START_DATETIME)  \
# 0    i*/*L*h*t*4*v*0*c*x*L*A*O*+*I*V*I*u*8*I*Z*0*         20180224104506
# 1    9*D*N*I*Y*A*8*9*c*5*E*u*E*T*C*U*+*G*q*9*J*I*         20170311161320
# 2    V*C*B*4*X*v*M*S*+*K*Z*w*+*N*5*0*h*0*i*F*E*M*                      ~
# 3    i*2*i*q*+*O*A*/*u*e*E*c*i*Q*R*5*O*2*u*T*M*c*                      ~
# 4    a*D*v*7*7*M*m*Y*3*I*f*3*G*U*a*/*7*T*b*z*a*k*         20170311035835
# ..                                            ...                    ...
# 495  B*8*2*y*4*1*T*6*J*b*7*/*P*1*r*m*K*4*C*A*Z*k*         20180824134928
# 496  C*G*I*8*M*L*K*t*u*W*O*x*/*X*K*m*1*J*n*R*4*0*                      ~
# 497  7*V*v*S*m*v*8*Y*B*M*F*8*/*4*7*V*D*X*s*2*e*8*         20191019141135
# 498  6*Y*i*9*f*4*k*v*3*W*c*2*A*f*G*1*4*I*0*W*c*A*                      ~
# 499  P*Z*L*t*x*g*X*E*m*j*Z*m*8*Q*2*G*Z*/*8*s*m*0*                      ~
#
#        교통수단_이름
# 0    지선버스(120)
# 1    지선버스(120)
# 2    마을버스(105)
# 3     서울도시철도공사
# ...

# %%
new_dictionary = new_df.set_index('카드번호(CARD_ID)').T.to_dict()

# %%
new_dictionary
# Out:
# {'i*/*L*h*t*4*v*0*c*x*L*A*O*+*I*V*I*u*8*I*Z*0*': {'운행출발일시(START_DATETIME)': '20180224104506',
#   '교통수단_이름': '지선버스(120)'},
#  '9*D*N*I*Y*A*8*9*c*5*E*u*E*T*C*U*+*G*q*9*J*I*': {'운행출발일시(START_DATETIME)': '20170311161320',
#   '교통수단_이름': '지선버스(120)'},
#  'V*C*B*4*X*v*M*S*+*K*Z*w*+*N*5*0*h*0*i*F*E*M*': {'운행출발일시(START_DATETIME)': '~',
#   '교통수단_이름': '마을버스(105)'},
#  'i*2*i*q*+*O*A*/*u*e*E*c*i*Q*R*5*O*2*u*T*M*c*': {'운행출발일시(START_DATETIME)': '~',
#   '교통수단_이름': '서울도시철도공사'},
#  'a*D*v*7*7*M*m*Y*3*I*f*3*G*U*a*/*7*T*b*z*a*k*': {'운행출발일시(START_DATETIME)': '20170311035835',
#   '교통수단_이름': '서울도시철도공사'},
#  'v*9*2*i*x*9*N*6*D*7*y*m*u*y*2*z*8*b*0*3*d*8*': {'운행출발일시(START_DATETIME)': '~',
#   '교통수단_이름': '마을버스(105)'},
#  'i*s*J*x*Z*F*i*p*y*S*V*T*t*6*I*F*x*U*Y*b*K*Y*': {'운행출발일시(START_DATETIME)': '20171222190111',
#   '교통수단_이름': '지선버스(120)'},
#  '+*4*f*S*X*O*6*x*O*w*J*t*x*x*c*8*d*B*p*D*6*c*': {'운행출발일시(START_DATETIME)': '20210531152617',
#   '교통수단_이름': '간선버스'},
# ...

# %%
import json

# %%
new_json = json.dumps(new_dictionary)

# %%
new_json
# Out:
# '{"i*/*L*h*t*4*v*0*c*x*L*A*O*+*I*V*I*u*8*I*Z*0*": {"\\uc6b4\\ud589\\ucd9c\\ubc1c\\uc77c\\uc2dc(START_DATETIME)": "20180224104506", "\\uad50\\ud1b5\\uc218\\ub2e8_\\uc774\\ub984": "\\uc9c0\\uc120\\ubc84\\uc2a4(120)"}, "9*D*N*I*Y*A*8*9*c*5*E*u*E*T*C*U*+*G*q*9*J*I*": {"\\uc6b4\\ud589\\ucd9c\\ubc1c\\uc77c\\uc2dc(START_DATETIME)": "20170311161320", "\\uad50\\ud1b5\\uc218\\ub2e8_\\uc774\\ub984": "\\uc9c0\\uc120\\ubc84\\uc2a4(120)"}, "V*C*B*4*X*v*M*S*+*K*Z*w*+*N*5*0*h*0*i*F*E*M*": {"\\uc6b4\\ud589\\ucd9c\\ubc1c\\uc77c\\uc2dc(START_DATETIME)": "~", "\\uad50\\ud1b5\\uc218\\ub2e8_\\uc774\\ub984": "\\ub9c8\\uc744\\ubc84\\uc2a4(105)"}, "i*2*i*q*+*O*A*/*u*e*E*c*i*Q*R*5*O*2*u*T*M*c*": {"\\uc6b4\\ud589\\ucd9c\\ubc1c\\uc77c\\uc2dc(START_DATETIME)": "~", "\\uad50\\ud1b5\\uc218\\ub2e8_\\uc774\\ub984": "\\uc11c\\uc6b8\\ub3c4\\uc2dc\\ucca0\\ub3c4\\uacf5\\uc0ac"}, "a*D*v*7*7*M*m*Y*3*I*f*3*G*U*a*/*7*T*b*z*a*k*": {"\\uc6b4\\ud589\\ucd9c\\ubc1c\\uc77c\\uc2dc(START_DATETIME)": "20170311035835", "\\uad50\\ud1b
# ...
