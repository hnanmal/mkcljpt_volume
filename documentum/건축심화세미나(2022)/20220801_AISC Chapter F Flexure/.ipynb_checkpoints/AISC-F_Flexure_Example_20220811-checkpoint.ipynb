# %%
# !pip install matplotlib

# %%
import csv
from dataclasses import dataclass, field, asdict, astuple
from typing import List
import math
import matplotlib.pyplot as plt

# %%
def importCSV(_path):
    with open(_path,'r') as f:
        reader  = csv.reader(f) # csv의 행별로 읽어옴

        res = [x for x in reader]
    return res

# %%
def exportCSV(_filename, _datas):
    f = open(_filename, 'w', newline='') # 자동줄바꿈 방지 header 이후 첫행 빈행 생성 방지
    csv_writer = csv.writer(f)
    
    for x in _datas:
        csv_writer.writerow(x)
    f.close()

# %% [markdown]
# # AISC 360-16 Chapter F
# # Design of Members for Flexure

# %% [markdown]
# <br>
#
# ## 단면 정보 import

# %%
input_path = 'Section Profile.csv'

# %%
dfSectionProfile = importCSV(input_path)
dfHeader = dfSectionProfile.pop(0) #pop(0)의 의미 첫행을 값을 반환하고 나머지 리스트는 저장

# %%
@dataclass # @의 의미 데코레이터 C언어의 Struct와 비슷한 쓰임새, 각 항목의 data 특성값 부여
class PreSection:
    ID: str
    Type: str
    h: str
    bf: str
    tw: str
    tf: str
    k: str
    
preSect1 = PreSection(*dfSectionProfile[294]) ##결과 확인용 코드

preSects = [PreSection(*x) for x in dfSectionProfile] ##결과 확인용 코드

preSects ##결과 확인용 코드
# Out:
# [PreSection(ID='W44X335', Type='W', h='1120', bf='404', tw='26.2', tf='45', k='65'),
#  PreSection(ID='W44X290', Type='W', h='1110', bf='401', tw='22', tf='40.1', k='59.9'),
#  PreSection(ID='W44X262', Type='W', h='1100', bf='401', tw='19.9', tf='36.1', k='55.9'),
#  PreSection(ID='W44X230', Type='W', h='1090', bf='401', tw='18', tf='31', k='51.1'),
#  PreSection(ID='W40X655', Type='W', h='1110', bf='429', tw='50', tf='89.9', k='120'),
#  PreSection(ID='W40X593', Type='W', h='1090', bf='424', tw='45.5', tf='82', k='112'),
#  PreSection(ID='W40X503', Type='W', h='1070', bf='417', tw='39.1', tf='70.1', k='100'),
#  PreSection(ID='W40X431', Type='W', h='1050', bf='411', tw='34', tf='59.9', k='89.9'),
#  PreSection(ID='W40X397', Type='W', h='1040', bf='409', tw='31', tf='55.9', k='85.9'),
#  PreSection(ID='W40X372', Type='W', h='1030', bf='409', tw='29.5', tf='52.1', k='82'),
#  PreSection(ID='W40X362', Type='W', h='1030', bf='406', tw='28.4', tf='51.1', k='81'),
#  PreSection(ID='W40X324', Type='W', h='1020', bf='404', tw='25.4', tf='46', k='75.9'),
#  PreSection(ID='W40X297', Type='W', h='1010', bf='401', tw='23.6', tf='41.9', k='71.9'),
#  PreSection(ID='W40X277', Type='W', h='1010', bf='401', tw='21.1', tf='40.1', k='70.1'),
#  PreSection(ID='W40X249', Type='W', h='1000', bf='401', tw='19.1', tf='36.1', k='66'),
#  PreSection(ID='W40X215', Type='W', h='991', bf='401', tw='16.5', tf='31', k='61'),
#  PreSection(ID='W40X199', Type='W', h='983', bf='401', tw='16.5', tf='27.2', k='57.2'),
#  PreSection(ID='W40X392', Type='W', h='1060', bf='315', tw='36.1', tf='64', k='94'),
#  PreSection(ID='W40X331', Type='W', h='1040', bf='310', tw='31', tf='54.1', k='84.1'),
#  PreSection(ID='W40X327', Type='W', h='1040', bf='307', tw='30', tf='54.1', k='84.1'),
#  PreSection(ID='W40X294', Type='W', h='1030', bf='305', tw='26.9', tf='49', k='79'),
#  PreSection(ID='W40X278', Type='W', h='1020', bf='305', tw='26.2', tf='46', k='75.9'),
#  PreSection(ID='W40X264', Type='W', h='1020', bf='302', tw='24.4', tf='43.9', k='73.9'),
#  PreSection(ID='W40X235', Type='W', h='1010', bf='302', tw='21.1', tf='40.1', k='70.1'),
#  PreSection(ID='W40X211', Type='W', h='1000', bf='300', tw='19.1', tf='36.1', k='66'),
#  PreSection(ID='W40X183', Type='W', h='991', bf='300', tw='16.5', tf='30.5', k='60.5'),
#  PreSection(ID='W40X167', Type='W', h='980', bf='300', tw='16.5', tf='26.2', k='56.1'),
#  PreSection(ID='W40X149', Type='W', h='970', bf='300', tw='16', tf='21.1', k='51.1'),
#  PreSection(ID='W36X925', Type='W', h='1090', bf='472', tw='76.7', tf='115', k='134'),
#  PreSection(ID='W36X853', Type='W', h='1090', bf='462', tw='64', tf='115', k='134'),
#  PreSection(ID='W36X802', Type='W', h='1080', bf='457', tw='60.5', tf='109', k='128'),
#  PreSection(ID='W36X723', Type='W', h='1060', bf='452', tw='55.1', tf='99.1', k='118'),
#  PreSection(ID='W36X652', Type='W', h='1040', bf='447', tw='50', tf='89.9', k='114'),
#  PreSection(ID='W36X529', Type='W', h='1010', bf='437', tw='40.9', tf='73.9', k='98'),
#  PreSection(ID='W36X487', Type='W', h='998', bf='434', tw='38.1', tf='68.1', k='92.2'),
#  PreSection(ID='W36X441', Type='W', h='988', bf='432', tw='34.5', tf='62', k='86.1'),
#  PreSection(ID='W36X395', Type='W', h='975', bf='427', tw='31', tf='55.9', k='80'),
#  PreSection(ID='W36X361', Type='W', h='965', bf='424', tw='28.4', tf='51.1', k='75.2'),
#  PreSection(ID='W36X330', Type='W', h='958', bf='422', tw='25.9', tf='47', k='71.1'),
#  PreSection(ID='W36X302', Type='W', h='947', bf='424', tw='24', tf='42.7', k='66.8'),
#  PreSection(ID='W36X282', Type='W', h='942', bf='422', tw='22.5', tf='39.9', k='64'),
#  PreSection(ID='W36X262', Type='W', h='937', bf='422', tw='21.3', tf='36.6', k='60.7'),
#  PreSection(ID='W36X247', Type='W', h='932', bf='419', tw='20.3', tf='34.3', k='58.4'),
#  PreSection(ID='W36X231', Type='W', h='927', bf='419', tw='19.3', tf='32', k='56.1'),
#  PreSection(ID='W36X256', Type='W', h='951', bf='310', tw='24.4', tf='43.9', k='63'),
#  PreSection(ID='W36X232', Type='W', h='943', bf='307', tw='22.1', tf='39.9', k='58.9'),
#  PreSection(ID='W36X210', Type='W', h='932', bf='310', tw='21.1', tf='34.5', k='53.6'),
#  PreSection(ID='W36X194', Type='W', h='927', bf='307', tw='19.4', tf='32', k='51.1'),
#  PreSection(ID='W36X182', Type='W', h='922', bf='307', tw='18.4', tf='30', k='49'),
#  PreSection(ID='W36X170', Type='W', h='919', bf='305', tw='17.3', tf='27.9', k='47'),
#  PreSection(ID='W36X160', Type='W', h='914', bf='305', tw='16.5', tf='25.9', k='45'),
#  PreSection(ID='W36X150', Type='W', h='912', bf='305', tw='15.9', tf='23.9', k='42.9'),
#  PreSection(ID='W36X135', Type='W', h='904', bf='305', tw='15.2', tf='20.1', k='39.1'),
#  PreSection(ID='W33X387', Type='W', h='914', bf='411', tw='32', tf='57.9', k='78'),
#  PreSection(ID='W33X354', Type='W', h='904', bf='409', tw='29.5', tf='53.1', k='73.2'),
#  PreSection(ID='W33X318', Type='W', h='894', bf='406', tw='26.4', tf='48', k='68.1'),
#  PreSection(ID='W33X291', Type='W', h='884', bf='404', tw='24.4', tf='43.9', k='64'),
#  PreSection(ID='W33X263', Type='W', h='876', bf='401', tw='22.1', tf='39.9', k='59.9'),
#  PreSection(ID='W33X241', Type='W', h='869', bf='404', tw='21.1', tf='35.6', k='55.6'),
#  PreSection(ID='W33X221', Type='W', h='861', bf='401', tw='19.7', tf='32.5', k='52.3'),
#  PreSection(ID='W33X201', Type='W', h='856', bf='399', tw='18.2', tf='29.2', k='49.3'),
#  PreSection(ID='W33X169', Type='W', h='859', bf='292', tw='17', tf='31', k='48.8'),
#  PreSection(ID='W33X152', Type='W', h='851', bf='295', tw='16.1', tf='26.9', k='44.7'),
#  PreSection(ID='W33X141', Type='W', h='846', bf='292', tw='15.4', tf='24.4', k='42.2'),
#  PreSection(ID='W33X130', Type='W', h='841', bf='292', tw='14.7', tf='21.7', k='39.6'),
#  PreSection(ID='W33X118', Type='W', h='836', bf='292', tw='14', tf='18.8', k='36.6'),
#  PreSection(ID='W30X391', Type='W', h='843', bf='396', tw='34.5', tf='62', k='82'),
#  PreSection(ID='W30X357', Type='W', h='833', bf='394', tw='31.5', tf='56.9', k='77'),
#  PreSection(ID='W30X326', Type='W', h='823', bf='391', tw='29', tf='52.1', k='72.1'),
#  PreSection(ID='W30X292', Type='W', h='813', bf='389', tw='25.9', tf='47', k='67.1'),
#  PreSection(ID='W30X261', Type='W', h='803', bf='386', tw='23.6', tf='41.9', k='62'),
#  PreSection(ID='W30X235', Type='W', h='795', bf='384', tw='21.1', tf='38.1', k='58.2'),
#  PreSection(ID='W30X211', Type='W', h='785', bf='384', tw='19.7', tf='33.5', k='53.3'),
#  PreSection(ID='W30X191', Type='W', h='780', bf='381', tw='18', tf='30.2', k='50'),
#  PreSection(ID='W30X173', Type='W', h='772', bf='381', tw='16.6', tf='27.2', k='47'),
#  PreSection(ID='W30X148', Type='W', h='780', bf='267', tw='16.5', tf='30', k='46.5'),
#  PreSection(ID='W30X132', Type='W', h='770', bf='267', tw='15.6', tf='25.4', k='41.9'),
#  PreSection(ID='W30X124', Type='W', h='767', bf='267', tw='14.9', tf='23.6', k='40.1'),
#  PreSection(ID='W30X116', Type='W', h='762', bf='267', tw='14.4', tf='21.6', k='38.1'),
#  PreSection(ID='W30X108', Type='W', h='757', bf='267', tw='13.8', tf='19.3', k='35.8'),
#  PreSection(ID='W30X99', Type='W', h='754', bf='267', tw='13.2', tf='17', k='33.5'),
#  PreSection(ID='W30X90', Type='W', h='749', bf='264', tw='11.9', tf='15.5', k='32'),
#  PreSection(ID='W27X539', Type='W', h='826', bf='389', tw='50', tf='89.9', k='110'),
#  PreSection(ID='W27X368', Type='W', h='772', bf='373', tw='35.1', tf='63', k='83.1'),
#  PreSection(ID='W27X336', Type='W', h='762', bf='371', tw='32', tf='57.9', k='78'),
#  PreSection(ID='W27X307', Type='W', h='752', bf='366', tw='29.5', tf='53.1', k='73.2'),
#  PreSection(ID='W27X281', Type='W', h='744', bf='366', tw='26.9', tf='49', k='69.1'),
#  PreSection(ID='W27X258', Type='W', h='737', bf='363', tw='24.9', tf='45', k='65'),
#  PreSection(ID='W27X235', Type='W', h='729', bf='361', tw='23.1', tf='40.9', k='61'),
#  PreSection(ID='W27X217', Type='W', h='721', bf='358', tw='21.1', tf='38.1', k='58.2'),
#  PreSection(ID='W27X194', Type='W', h='714', bf='356', tw='19.1', tf='34', k='54.1'),
#  PreSection(ID='W27X178', Type='W', h='706', bf='358', tw='18.4', tf='30.2', k='50.3'),
#  PreSection(ID='W27X161', Type='W', h='701', bf='356', tw='16.8', tf='27.4', k='47.5'),
#  PreSection(ID='W27X146', Type='W', h='696', bf='356', tw='15.4', tf='24.8', k='44.7'),
#  PreSection(ID='W27X129', Type='W', h='701', bf='254', tw='15.5', tf='27.9', k='43.2'),
#  PreSection(ID='W27X114', Type='W', h='693', bf='257', tw='14.5', tf='23.6', k='38.9'),
#  PreSection(ID='W27X102', Type='W', h='688', bf='254', tw='13.1', tf='21.1', k='36.3'),
#  PreSection(ID='W27X94', Type='W', h='683', bf='254', tw='12.4', tf='18.9', k='34'),
#  PreSection(ID='W27X84', Type='W', h='678', bf='254', tw='11.7', tf='16.3', k='31.5'),
#  PreSection(ID='W24X370', Type='W', h='711', bf='348', tw='38.6', tf='69.1', k='81.8'),
#  PreSection(ID='W24X335', Type='W', h='699', bf='343', tw='35.1', tf='63', k='75.7'),
#  PreSection(ID='W24X306', Type='W', h='688', bf='340', tw='32', tf='57.9', k='70.6'),
#  PreSection(ID='W24X279', Type='W', h='678', bf='338', tw='29.5', tf='53.1', k='65.8'),
#  PreSection(ID='W24X250', Type='W', h='668', bf='335', tw='26.4', tf='48', k='60.7'),
#  PreSection(ID='W24X229', Type='W', h='660', bf='333', tw='24.4', tf='43.9', k='56.6'),
#  PreSection(ID='W24X207', Type='W', h='653', bf='330', tw='22.1', tf='39.9', k='52.6'),
#  PreSection(ID='W24X192', Type='W', h='648', bf='330', tw='20.6', tf='37.1', k='49.8'),
#  PreSection(ID='W24X176', Type='W', h='640', bf='328', tw='19.1', tf='34', k='46.7'),
#  PreSection(ID='W24X162', Type='W', h='635', bf='330', tw='17.9', tf='31', k='43.7'),
#  PreSection(ID='W24X146', Type='W', h='627', bf='328', tw='16.5', tf='27.7', k='40.4'),
#  PreSection(ID='W24X131', Type='W', h='622', bf='328', tw='15.4', tf='24.4', k='37.1'),
#  PreSection(ID='W24X117', Type='W', h='617', bf='325', tw='14', tf='21.6', k='34.3'),
#  PreSection(ID='W24X104', Type='W', h='612', bf='325', tw='12.7', tf='19.1', k='31.8'),
#  PreSection(ID='W24X103', Type='W', h='622', bf='229', tw='14', tf='24.9', k='37.6'),
#  PreSection(ID='W24X94', Type='W', h='617', bf='230', tw='13.1', tf='22.2', k='35.1'),
#  PreSection(ID='W24X84', Type='W', h='612', bf='229', tw='11.9', tf='19.6', k='32.3'),
#  PreSection(ID='W24X76', Type='W', h='607', bf='228', tw='11.2', tf='17.3', k='30'),
#  PreSection(ID='W24X68', Type='W', h='602', bf='228', tw='10.5', tf='14.9', k='27.7'),
#  PreSection(ID='W24X62', Type='W', h='602', bf='179', tw='10.9', tf='15', k='27.7'),
#  PreSection(ID='W24X55', Type='W', h='599', bf='178', tw='10', tf='12.8', k='25.7'),
#  PreSection(ID='W21X275', Type='W', h='612', bf='328', tw='31', tf='55.6', k='85.6'),
#  PreSection(ID='W21X248', Type='W', h='602', bf='325', tw='27.9', tf='50.5', k='80.5'),
#  PreSection(ID='W21X223', Type='W', h='594', bf='323', tw='25.4', tf='45.5', k='75.4'),
#  PreSection(ID='W21X201', Type='W', h='584', bf='320', tw='23.1', tf='41.4', k='54.1'),
#  PreSection(ID='W21X182', Type='W', h='577', bf='318', tw='21.1', tf='37.6', k='50.3'),
#  PreSection(ID='W21X166', Type='W', h='572', bf='315', tw='19.1', tf='34.5', k='47.2'),
#  PreSection(ID='W21X147', Type='W', h='561', bf='318', tw='18.3', tf='29.2', k='41.9'),
#  PreSection(ID='W21X132', Type='W', h='554', bf='315', tw='16.5', tf='26.4', k='39.1'),
#  PreSection(ID='W21X122', Type='W', h='551', bf='315', tw='15.2', tf='24.4', k='37.1'),
#  PreSection(ID='W21X111', Type='W', h='546', bf='312', tw='14', tf='22.2', k='35.1'),
#  PreSection(ID='W21X101', Type='W', h='544', bf='312', tw='12.7', tf='20.3', k='33'),
#  PreSection(ID='W21X93', Type='W', h='549', bf='214', tw='14.7', tf='23.6', k='36.3'),
#  PreSection(ID='W21X83', Type='W', h='544', bf='212', tw='13.1', tf='21.2', k='34'),
#  PreSection(ID='W21X73', Type='W', h='538', bf='211', tw='11.6', tf='18.8', k='31.5'),
#  PreSection(ID='W21X68', Type='W', h='536', bf='210', tw='10.9', tf='17.4', k='30.2'),
#  PreSection(ID='W21X62', Type='W', h='533', bf='209', tw='10.2', tf='15.6', k='28.4'),
#  PreSection(ID='W21X55', Type='W', h='528', bf='209', tw='9.53', tf='13.3', k='25.9'),
#  PreSection(ID='W21X48', Type='W', h='523', bf='207', tw='8.89', tf='10.9', k='23.6'),
#  PreSection(ID='W21X57', Type='W', h='536', bf='167', tw='10.3', tf='16.5', k='29.2'),
#  PreSection(ID='W21X50', Type='W', h='528', bf='166', tw='9.65', tf='13.6', k='26.4'),
#  PreSection(ID='W21X44', Type='W', h='526', bf='165', tw='8.89', tf='11.4', k='24.1'),
#  PreSection(ID='W18X311', Type='W', h='566', bf='305', tw='38.6', tf='69.6', k='82.3'),
#  PreSection(ID='W18X283', Type='W', h='556', bf='302', tw='35.6', tf='63.5', k='76.2'),
#  PreSection(ID='W18X258', Type='W', h='546', bf='300', tw='32.5', tf='58.4', k='68.6'),
#  PreSection(ID='W18X234', Type='W', h='536', bf='297', tw='29.5', tf='53.6', k='63.8'),
#  PreSection(ID='W18X211', Type='W', h='526', bf='295', tw='26.9', tf='48.5', k='58.7'),
#  PreSection(ID='W18X192', Type='W', h='518', bf='292', tw='24.4', tf='44.5', k='54.6'),
#  PreSection(ID='W18X175', Type='W', h='508', bf='290', tw='22.6', tf='40.4', k='50.5'),
#  PreSection(ID='W18X158', Type='W', h='500', bf='287', tw='20.6', tf='36.6', k='46.7'),
#  PreSection(ID='W18X143', Type='W', h='495', bf='284', tw='18.5', tf='33.5', k='43.7'),
#  PreSection(ID='W18X130', Type='W', h='490', bf='284', tw='17', tf='30.5', k='40.6'),
#  PreSection(ID='W18X119', Type='W', h='483', bf='287', tw='16.6', tf='26.9', k='37.1'),
#  PreSection(ID='W18X106', Type='W', h='475', bf='284', tw='15', tf='23.9', k='34'),
#  PreSection(ID='W18X97', Type='W', h='472', bf='282', tw='13.6', tf='22.1', k='32.3'),
#  PreSection(ID='W18X86', Type='W', h='467', bf='282', tw='12.2', tf='19.6', k='29.7'),
#  PreSection(ID='W18X76', Type='W', h='462', bf='279', tw='10.8', tf='17.3', k='27.4'),
#  PreSection(ID='W18X71', Type='W', h='470', bf='194', tw='12.6', tf='20.6', k='30.7'),
#  PreSection(ID='W18X65', Type='W', h='467', bf='193', tw='11.4', tf='19.1', k='29.2'),
#  PreSection(ID='W18X60', Type='W', h='462', bf='192', tw='10.5', tf='17.7', k='27.9'),
#  PreSection(ID='W18X55', Type='W', h='460', bf='191', tw='9.91', tf='16', k='26.2'),
#  PreSection(ID='W18X50', Type='W', h='457', bf='191', tw='9.02', tf='14.5', k='24.7'),
#  PreSection(ID='W18X46', Type='W', h='460', bf='154', tw='9.14', tf='15.4', k='25.7'),
#  PreSection(ID='W18X40', Type='W', h='455', bf='153', tw='8', tf='13.3', k='23.5'),
#  PreSection(ID='W18X35', Type='W', h='450', bf='152', tw='7.62', tf='10.8', k='21'),
#  PreSection(ID='W16X100', Type='W', h='432', bf='264', tw='14.9', tf='25', k='35.3'),
#  PreSection(ID='W16X89', Type='W', h='427', bf='264', tw='13.3', tf='22.2', k='32.5'),
#  PreSection(ID='W16X77', Type='W', h='419', bf='262', tw='11.6', tf='19.3', k='29.5'),
#  PreSection(ID='W16X67', Type='W', h='414', bf='259', tw='10', tf='16.9', k='27.2'),
#  PreSection(ID='W16X57', Type='W', h='417', bf='181', tw='10.9', tf='18.2', k='28.4'),
#  PreSection(ID='W16X50', Type='W', h='414', bf='180', tw='9.65', tf='16', k='26.2'),
#  PreSection(ID='W16X45', Type='W', h='409', bf='179', tw='8.76', tf='14.4', k='24.6'),
#  PreSection(ID='W16X40', Type='W', h='406', bf='178', tw='7.75', tf='12.8', k='23'),
#  PreSection(ID='W16X36', Type='W', h='404', bf='178', tw='7.49', tf='10.9', k='21.1'),
#  PreSection(ID='W16X31', Type='W', h='404', bf='140', tw='6.99', tf='11.2', k='21.4'),
#  PreSection(ID='W16X26', Type='W', h='399', bf='140', tw='6.35', tf='8.76', k='19'),
#  PreSection(ID='W14X873', Type='W', h='599', bf='478', tw='100', tf='140', k='155'),
#  PreSection(ID='W14X808', Type='W', h='579', bf='472', tw='95', tf='130', k='145'),
#  PreSection(ID='W14X730', Type='W', h='569', bf='455', tw='78', tf='125', k='140'),
#  PreSection(ID='W14X665', Type='W', h='549', bf='450', tw='71.9', tf='115', k='130'),
#  PreSection(ID='W14X605', Type='W', h='531', bf='442', tw='66', tf='106', k='121'),
#  PreSection(ID='W14X550', Type='W', h='513', bf='437', tw='60.5', tf='97', k='112'),
#  PreSection(ID='W14X500', Type='W', h='498', bf='432', tw='55.6', tf='88.9', k='104'),
#  PreSection(ID='W14X455', Type='W', h='483', bf='427', tw='51.3', tf='81.5', k='96.8'),
#  PreSection(ID='W14X426', Type='W', h='475', bf='424', tw='47.8', tf='77.2', k='92.2'),
#  PreSection(ID='W14X398', Type='W', h='465', bf='422', tw='45', tf='72.4', k='87.4'),
#  PreSection(ID='W14X370', Type='W', h='455', bf='419', tw='42.2', tf='67.6', k='82.8'),
#  PreSection(ID='W14X342', Type='W', h='445', bf='417', tw='39.1', tf='62.7', k='78'),
#  PreSection(ID='W14X311', Type='W', h='434', bf='411', tw='35.8', tf='57.4', k='72.6'),
#  PreSection(ID='W14X283', Type='W', h='424', bf='409', tw='32.8', tf='52.6', k='67.8'),
#  PreSection(ID='W14X257', Type='W', h='417', bf='406', tw='30', tf='48', k='63.2'),
#  PreSection(ID='W14X233', Type='W', h='406', bf='404', tw='27.2', tf='43.7', k='58.9'),
#  PreSection(ID='W14X211', Type='W', h='399', bf='401', tw='24.9', tf='39.6', k='54.9'),
#  PreSection(ID='W14X193', Type='W', h='394', bf='399', tw='22.6', tf='36.6', k='51.8'),
#  PreSection(ID='W14X176', Type='W', h='386', bf='399', tw='21.1', tf='33.3', k='48.5'),
#  PreSection(ID='W14X159', Type='W', h='381', bf='396', tw='18.9', tf='30.2', k='45.5'),
#  PreSection(ID='W14X145', Type='W', h='376', bf='394', tw='17.3', tf='27.7', k='42.9'),
#  PreSection(ID='W14X132', Type='W', h='373', bf='373', tw='16.4', tf='26.2', k='41.4'),
#  PreSection(ID='W14X120', Type='W', h='368', bf='373', tw='15', tf='23.9', k='39.1'),
#  PreSection(ID='W14X109', Type='W', h='363', bf='371', tw='13.3', tf='21.8', k='37.1'),
#  PreSection(ID='W14X99', Type='W', h='361', bf='371', tw='12.3', tf='19.8', k='35.1'),
#  PreSection(ID='W14X90', Type='W', h='356', bf='368', tw='11.2', tf='18', k='33.3'),
#  PreSection(ID='W14X82', Type='W', h='363', bf='257', tw='13', tf='21.7', k='36.8'),
#  PreSection(ID='W14X74', Type='W', h='361', bf='257', tw='11.4', tf='19.9', k='35.1'),
#  PreSection(ID='W14X68', Type='W', h='356', bf='254', tw='10.5', tf='18.3', k='33.3'),
#  PreSection(ID='W14X61', Type='W', h='353', bf='254', tw='9.53', tf='16.4', k='31.5'),
#  PreSection(ID='W14X53', Type='W', h='353', bf='205', tw='9.4', tf='16.8', k='31.8'),
#  PreSection(ID='W14X48', Type='W', h='351', bf='204', tw='8.64', tf='15.1', k='30.2'),
#  PreSection(ID='W14X43', Type='W', h='348', bf='203', tw='7.75', tf='13.5', k='28.4'),
#  PreSection(ID='W14X38', Type='W', h='358', bf='172', tw='7.87', tf='13.1', k='23.2'),
#  PreSection(ID='W14X34', Type='W', h='356', bf='171', tw='7.24', tf='11.6', k='21.7'),
#  PreSection(ID='W14X30', Type='W', h='351', bf='171', tw='6.86', tf='9.78', k='19.9'),
#  PreSection(ID='W14X26', Type='W', h='353', bf='128', tw='6.48', tf='10.7', k='20.8'),
#  PreSection(ID='W14X22', Type='W', h='348', bf='127', tw='5.84', tf='8.51', k='18.7'),
#  PreSection(ID='W12X336', Type='W', h='427', bf='340', tw='45.2', tf='75.2', k='90.2'),
#  PreSection(ID='W12X305', Type='W', h='414', bf='335', tw='41.4', tf='68.8', k='83.8'),
#  PreSection(ID='W12X279', Type='W', h='404', bf='333', tw='38.9', tf='62.7', k='78'),
#  PreSection(ID='W12X252', Type='W', h='391', bf='330', tw='35.6', tf='57.2', k='72.4'),
#  PreSection(ID='W12X230', Type='W', h='384', bf='328', tw='32.8', tf='52.6', k='67.8'),
#  PreSection(ID='W12X210', Type='W', h='373', bf='325', tw='30', tf='48.3', k='63.5'),
#  PreSection(ID='W12X190', Type='W', h='366', bf='323', tw='26.9', tf='44.2', k='59.2'),
#  PreSection(ID='W12X170', Type='W', h='356', bf='320', tw='24.4', tf='39.6', k='54.9'),
#  PreSection(ID='W12X152', Type='W', h='348', bf='318', tw='22.1', tf='35.6', k='50.8'),
#  PreSection(ID='W12X136', Type='W', h='340', bf='315', tw='20.1', tf='31.8', k='47'),
#  PreSection(ID='W12X120', Type='W', h='333', bf='312', tw='18', tf='28.2', k='43.2'),
#  PreSection(ID='W12X106', Type='W', h='328', bf='310', tw='15.5', tf='25.1', k='40.4'),
#  PreSection(ID='W12X96', Type='W', h='323', bf='310', tw='14', tf='22.9', k='38.1'),
#  PreSection(ID='W12X87', Type='W', h='318', bf='307', tw='13.1', tf='20.6', k='35.8'),
#  PreSection(ID='W12X79', Type='W', h='315', bf='307', tw='11.9', tf='18.7', k='33.8'),
#  PreSection(ID='W12X72', Type='W', h='312', bf='305', tw='10.9', tf='17', k='32.3'),
#  PreSection(ID='W12X65', Type='W', h='307', bf='305', tw='9.91', tf='15.4', k='30.5'),
#  PreSection(ID='W12X58', Type='W', h='310', bf='254', tw='9.14', tf='16.3', k='31.5'),
#  PreSection(ID='W12X53', Type='W', h='307', bf='254', tw='8.76', tf='14.6', k='30'),
#  PreSection(ID='W12X50', Type='W', h='310', bf='205', tw='9.4', tf='16.3', k='29'),
#  PreSection(ID='W12X45', Type='W', h='307', bf='204', tw='8.51', tf='14.6', k='27.4'),
#  PreSection(ID='W12X40', Type='W', h='302', bf='203', tw='7.49', tf='13.1', k='25.9'),
#  PreSection(ID='W12X35', Type='W', h='318', bf='167', tw='7.62', tf='13.2', k='20.8'),
#  PreSection(ID='W12X30', Type='W', h='312', bf='166', tw='6.6', tf='11.2', k='18.8'),
#  PreSection(ID='W12X26', Type='W', h='310', bf='165', tw='5.84', tf='9.65', k='17.3'),
#  PreSection(ID='W12X22', Type='W', h='312', bf='102', tw='6.6', tf='10.8', k='18.4'),
#  PreSection(ID='W12X19', Type='W', h='310', bf='102', tw='5.97', tf='8.89', k='16.5'),
#  PreSection(ID='W12X16', Type='W', h='305', bf='101', tw='5.59', tf='6.73', k='14.4'),
#  PreSection(ID='W12X14', Type='W', h='302', bf='101', tw='5.08', tf='5.72', k='13.3'),
#  PreSection(ID='W10X112', Type='W', h='290', bf='264', tw='19.2', tf='31.8', k='44.5'),
#  PreSection(ID='W10X100', Type='W', h='282', bf='262', tw='17.3', tf='28.4', k='41.1'),
#  PreSection(ID='W10X88', Type='W', h='274', bf='262', tw='15.4', tf='25.1', k='37.8'),
#  PreSection(ID='W10X77', Type='W', h='269', bf='259', tw='13.5', tf='22.1', k='34.8'),
#  PreSection(ID='W10X68', Type='W', h='264', bf='257', tw='11.9', tf='19.6', k='32.3'),
#  PreSection(ID='W10X60', Type='W', h='259', bf='257', tw='10.7', tf='17.3', k='30'),
#  PreSection(ID='W10X54', Type='W', h='257', bf='254', tw='9.4', tf='15.6', k='28.4'),
#  PreSection(ID='W10X49', Type='W', h='254', bf='254', tw='8.64', tf='14.2', k='26.9'),
#  PreSection(ID='W10X45', Type='W', h='257', bf='204', tw='8.89', tf='15.7', k='28.4'),
#  PreSection(ID='W10X39', Type='W', h='252', bf='203', tw='8', tf='13.5', k='26.2'),
#  PreSection(ID='W10X33', Type='W', h='247', bf='202', tw='7.37', tf='11', k='23.7'),
#  PreSection(ID='W10X30', Type='W', h='267', bf='148', tw='7.62', tf='13', k='20.6'),
#  PreSection(ID='W10X26', Type='W', h='262', bf='147', tw='6.6', tf='11.2', k='18.8'),
#  PreSection(ID='W10X22', Type='W', h='259', bf='146', tw='6.1', tf='9.14', k='16.8'),
#  PreSection(ID='W10X19', Type='W', h='259', bf='102', tw='6.35', tf='10', k='17.7'),
#  PreSection(ID='W10X17', Type='W', h='257', bf='102', tw='6.1', tf='8.38', k='16'),
#  PreSection(ID='W10X15', Type='W', h='254', bf='102', tw='5.84', tf='6.86', k='14.5'),
#  PreSection(ID='W10X12', Type='W', h='251', bf='101', tw='4.83', tf='5.33', k='13'),
#  PreSection(ID='W8X67', Type='W', h='229', bf='210', tw='14.5', tf='23.7', k='33.8'),
#  PreSection(ID='W8X58', Type='W', h='222', bf='209', tw='13', tf='20.6', k='30.5'),
#  PreSection(ID='W8X48', Type='W', h='216', bf='206', tw='10.2', tf='17.4', k='27.4'),
#  PreSection(ID='W8X40', Type='W', h='210', bf='205', tw='9.14', tf='14.2', k='24.2'),
#  PreSection(ID='W8X35', Type='W', h='206', bf='204', tw='7.87', tf='12.6', k='22.6'),
#  PreSection(ID='W8X31', Type='W', h='203', bf='203', tw='7.24', tf='11', k='21.1'),
#  PreSection(ID='W8X28', Type='W', h='205', bf='166', tw='7.24', tf='11.8', k='21.8'),
#  PreSection(ID='W8X24', Type='W', h='201', bf='165', tw='6.22', tf='10.2', k='20.2'),
#  PreSection(ID='W8X21', Type='W', h='210', bf='134', tw='6.35', tf='10.2', k='17.8'),
#  PreSection(ID='W8X18', Type='W', h='207', bf='133', tw='5.84', tf='8.38', k='16'),
#  PreSection(ID='W8X15', Type='W', h='206', bf='102', tw='6.22', tf='8', k='15.6'),
#  PreSection(ID='W8X13', Type='W', h='203', bf='102', tw='5.84', tf='6.48', k='14.1'),
#  PreSection(ID='W8X10', Type='W', h='200', bf='100', tw='4.32', tf='5.21', k='12.8'),
#  PreSection(ID='W6X25', Type='W', h='162', bf='154', tw='8.13', tf='11.6', k='17.9'),
#  PreSection(ID='W6X20', Type='W', h='157', bf='153', tw='6.6', tf='9.27', k='15.6'),
#  PreSection(ID='W6X15', Type='W', h='152', bf='152', tw='5.84', tf='6.6', k='13'),
#  PreSection(ID='W6X16', Type='W', h='160', bf='102', tw='6.6', tf='10.3', k='16.6'),
#  PreSection(ID='W6X12', Type='W', h='153', bf='102', tw='5.84', tf='7.11', k='13.5'),
#  PreSection(ID='W6X9', Type='W', h='150', bf='100', tw='4.32', tf='5.46', k='11.8'),
#  PreSection(ID='W6X8.5', Type='W', h='148', bf='100', tw='4.32', tf='4.95', k='11.3'),
#  PreSection(ID='W5X19', Type='W', h='131', bf='128', tw='6.86', tf='10.9', k='18.5'),
#  PreSection(ID='W5X16', Type='W', h='127', bf='127', tw='6.1', tf='9.14', k='16.8'),
#  PreSection(ID='W4X13', Type='W', h='106', bf='103', tw='7.11', tf='8.76', k='15.1'),
#  PreSection(ID='H-100×100x6x8', Type='H', h='100', bf='100', tw='6', tf='8', k='10'),
#  PreSection(ID='H-125×125x6.5x9', Type='H', h='125', bf='125', tw='6.5', tf='9', k='10'),
#  PreSection(ID='H-150×75x5x7', Type='H', h='150', bf='75', tw='5', tf='7', k='8'),
#  PreSection(ID='H-148×100x6x9', Type='H', h='148', bf='100', tw='6', tf='9', k='11'),
#  PreSection(ID='H-150×150x7x10', Type='H', h='150', bf='150', tw='7', tf='10', k='11'),
#  PreSection(ID='H-198×99x4.5x7', Type='H', h='198', bf='99', tw='4.5', tf='7', k='11'),
#  PreSection(ID='H-200×100x5.5x8', Type='H', h='200', bf='100', tw='5.5', tf='8', k='11'),
#  PreSection(ID='H-194×150x6x9', Type='H', h='194', bf='150', tw='6', tf='9', k='13'),
#  PreSection(ID='H-200×200x8x12', Type='H', h='200', bf='200', tw='8', tf='12', k='13'),
#  PreSection(ID='H-200×204x12x12', Type='H', h='200', bf='204', tw='12', tf='12', k='13'),
#  PreSection(ID='H-208×202x10x16', Type='H', h='208', bf='202', tw='10', tf='16', k='13'),
#  PreSection(ID='H-248×124x5x8', Type='H', h='248', bf='124', tw='5', tf='8', k='12'),
#  PreSection(ID='H-250×125x6x9', Type='H', h='250', bf='125', tw='6', tf='9', k='12'),
#  PreSection(ID='H-244×175x7x11', Type='H', h='244', bf='175', tw='7', tf='11', k='16'),
#  PreSection(ID='H-244×252x11x11', Type='H', h='244', bf='252', tw='11', tf='11', k='16'),
#  PreSection(ID='H-248×249x8x13', Type='H', h='248', bf='249', tw='8', tf='13', k='16'),
#  PreSection(ID='H-250×250x9x14', Type='H', h='250', bf='250', tw='9', tf='14', k='16'),
#  PreSection(ID='H-250×255x14x14', Type='H', h='250', bf='255', tw='14', tf='14', k='16'),
#  PreSection(ID='H-298×149x5.5x8', Type='H', h='298', bf='149', tw='5.5', tf='8', k='13'),
#  PreSection(ID='H-300×150x6.5x9', Type='H', h='300', bf='150', tw='6.5', tf='9', k='13'),
#  PreSection(ID='H-294×200x8x12', Type='H', h='294', bf='200', tw='8', tf='12', k='18'),
#  PreSection(ID='H-298×201x9x14', Type='H', h='298', bf='201', tw='9', tf='14', k='18'),
#  PreSection(ID='H-294×302x12x12', Type='H', h='294', bf='302', tw='12', tf='12', k='18'),
#  PreSection(ID='H-298×299x9x14', Type='H', h='298', bf='299', tw='9', tf='14', k='18'),
#  PreSection(ID='H-300×300x10x15', Type='H', h='300', bf='300', tw='10', tf='15', k='18'),
#  PreSection(ID='H-300×305x15x15', Type='H', h='300', bf='305', tw='15', tf='15', k='18'),
#  PreSection(ID='H-304×301x11x17', Type='H', h='304', bf='301', tw='11', tf='17', k='18'),
#  PreSection(ID='H-310×305x15x20', Type='H', h='310', bf='305', tw='15', tf='20', k='18'),
#  PreSection(ID='H-310×310x20x20', Type='H', h='310', bf='310', tw='20', tf='20', k='18'),
#  PreSection(ID='H-346×174x6x9', Type='H', h='346', bf='174', tw='6', tf='9', k='14'),
#  PreSection(ID='H-350×175x7x11', Type='H', h='350', bf='175', tw='7', tf='11', k='14'),
#  PreSection(ID='H-354×176x8x13', Type='H', h='354', bf='176', tw='8', tf='13', k='14'),
#  PreSection(ID='H-336×249x8x12', Type='H', h='336', bf='249', tw='8', tf='12', k='20'),
#  PreSection(ID='H-340×250x9x14', Type='H', h='340', bf='250', tw='9', tf='14', k='20'),
#  PreSection(ID='H-338×351x13x13', Type='H', h='338', bf='351', tw='13', tf='13', k='20'),
#  PreSection(ID='H-344×348x10x16', Type='H', h='344', bf='348', tw='10', tf='16', k='20'),
#  PreSection(ID='H-344×354x16x16', Type='H', h='344', bf='354', tw='16', tf='16', k='20'),
#  PreSection(ID='H-350×350x12x19', Type='H', h='350', bf='350', tw='12', tf='19', k='20'),
#  PreSection(ID='H-350×357x19x19', Type='H', h='350', bf='357', tw='19', tf='19', k='20'),
#  PreSection(ID='H-396×199x7x11', Type='H', h='396', bf='199', tw='7', tf='11', k='16'),
#  PreSection(ID='H-400×200x8x13', Type='H', h='400', bf='200', tw='8', tf='13', k='16'),
#  PreSection(ID='H-404×201x9x15', Type='H', h='404', bf='201', tw='9', tf='15', k='16'),
#  PreSection(ID='H-386×299x9x14', Type='H', h='386', bf='299', tw='9', tf='14', k='22'),
#  PreSection(ID='H-390×300x10x16', Type='H', h='390', bf='300', tw='10', tf='16', k='22'),
#  PreSection(ID='H-388×402x15x15', Type='H', h='388', bf='402', tw='15', tf='15', k='22'),
#  PreSection(ID='H-394×398x11x18', Type='H', h='394', bf='398', tw='11', tf='18', k='22'),
#  PreSection(ID='H-394×405x18x18', Type='H', h='394', bf='405', tw='18', tf='18', k='22'),
#  PreSection(ID='H-400×400x13x21', Type='H', h='400', bf='400', tw='13', tf='21', k='22'),
#  PreSection(ID='H-400×408x21x21', Type='H', h='400', bf='408', tw='21', tf='21', k='22'),
#  PreSection(ID='H-406×403x16x24', Type='H', h='406', bf='403', tw='16', tf='24', k='22'),
#  PreSection(ID='H-414×405x18x28', Type='H', h='414', bf='405', tw='18', tf='28', k='22'),
#  PreSection(ID='H-428×407x20x35', Type='H', h='428', bf='407', tw='20', tf='35', k='22'),
#  PreSection(ID='H-458×417x30x50', Type='H', h='458', bf='417', tw='30', tf='50', k='22'),
#  PreSection(ID='H-498×432x45x70', Type='H', h='498', bf='432', tw='45', tf='70', k='22'),
#  PreSection(ID='H-446×199x8x12', Type='H', h='446', bf='199', tw='8', tf='12', k='18'),
#  PreSection(ID='H-450×200x9x14', Type='H', h='450', bf='200', tw='9', tf='14', k='18'),
#  PreSection(ID='H-434×299x10x15', Type='H', h='434', bf='299', tw='10', tf='15', k='24'),
#  PreSection(ID='H-440×300x11x18', Type='H', h='440', bf='300', tw='11', tf='18', k='24'),
#  PreSection(ID='H-496×199x9x14', Type='H', h='496', bf='199', tw='9', tf='14', k='20'),
#  PreSection(ID='H-500×200x10x16', Type='H', h='500', bf='200', tw='10', tf='16', k='20'),
#  PreSection(ID='H-506×201x11x19', Type='H', h='506', bf='201', tw='11', tf='19', k='20'),
#  PreSection(ID='H-482×300x11x15', Type='H', h='482', bf='300', tw='11', tf='15', k='26'),
#  PreSection(ID='H-488×300x11x18', Type='H', h='488', bf='300', tw='11', tf='18', k='26'),
#  PreSection(ID='H-596×199x10x15', Type='H', h='596', bf='199', tw='10', tf='15', k='22'),
#  PreSection(ID='H-600×200x11x17', Type='H', h='600', bf='200', tw='11', tf='17', k='22'),
#  PreSection(ID='H-606×201x12x20', Type='H', h='606', bf='201', tw='12', tf='20', k='22'),
#  PreSection(ID='H-612×202x13x23', Type='H', h='612', bf='202', tw='13', tf='23', k='22'),
#  PreSection(ID='H-582×300x12x17', Type='H', h='582', bf='300', tw='12', tf='17', k='28'),
#  PreSection(ID='H-588×300x12x20', Type='H', h='588', bf='300', tw='12', tf='20', k='28'),
#  PreSection(ID='H-594×302x14x23', Type='H', h='594', bf='302', tw='14', tf='23', k='28'),
#  PreSection(ID='H-692×300x13x20', Type='H', h='692', bf='300', tw='13', tf='20', k='28'),
#  PreSection(ID='H-700×300x13x24', Type='H', h='700', bf='300', tw='13', tf='24', k='28'),
#  PreSection(ID='H-708×302x15x28', Type='H', h='708', bf='302', tw='15', tf='28', k='28'),
#  PreSection(ID='H-792×300x14x22', Type='H', h='792', bf='300', tw='14', tf='22', k='28'),
#  PreSection(ID='H-800×300x14x26', Type='H', h='800', bf='300', tw='14', tf='26', k='28'),
#  PreSection(ID='H-808×302x16x30', Type='H', h='808', bf='302', tw='16', tf='30', k='28'),
#  PreSection(ID='H-890×299x15x23', Type='H', h='890', bf='299', tw='15', tf='23', k='18'),
#  PreSection(ID='H-900×300x16x28', Type='H', h='900', bf='300', tw='16', tf='28', k='18'),
#  PreSection(ID='H-912×302x18x34', Type='H', h='912', bf='302', tw='18', tf='34', k='18'),
#  PreSection(ID='H-918×303x19x37', Type='H', h='918', bf='303', tw='19', tf='37', k='18'),
#  PreSection(ID='BH-1000x400x15x30', Type='BH', h='1000', bf='400', tw='15', tf='30', k='28'),
#  PreSection(ID='BH-2200x350x10x30', Type='BH', h='2200', bf='350', tw='10', tf='30', k='28'),
#  PreSection(ID='BH-700x350x10x30', Type='BH', h='700', bf='350', tw='10', tf='30', k='28'),
#  PreSection(ID='BH-2200x300x10x25', Type='BH', h='2200', bf='300', tw='10', tf='25', k='28'),
#  PreSection(ID='BH-1500x300x10x25', Type='BH', h='1500', bf='300', tw='10', tf='25', k='28'),
#  PreSection(ID='BH-1800x300x10x25', Type='BH', h='1800', bf='300', tw='10', tf='25', k='28'),
#  PreSection(ID='BH-700x300x10x25', Type='BH', h='700', bf='300', tw='10', tf='25', k='28'),
#  PreSection(ID='BH-2200x350x10x25', Type='BH', h='2200', bf='350', tw='10', tf='25', k='28'),
#  PreSection(ID='BH-1500x350x10x25', Type='BH', h='1500', bf='350', tw='10', tf='25', k='28'),
#  PreSection(ID='BH-1200x300x10x25', Type='BH', h='1200', bf='300', tw='10', tf='25', k='28'),
#  PreSection(ID='BH-700x350x10x25', Type='BH', h='700', bf='350', tw='10', tf='25', k='28'),
#  PreSection(ID='BH-2200x350x15x30', Type='BH', h='2200', bf='350', tw='15', tf='30', k='28'),
#  PreSection(ID='BH-1500x350x15x30', Type='BH', h='1500', bf='350', tw='15', tf='30', k='28'),
#  PreSection(ID='BH-1800x350x15x30', Type='BH', h='1800', bf='350', tw='15', tf='30', k='28')]

# %%
targetSection = PreSection(*dfSectionProfile[160])
targetSection
# Out:
# PreSection(ID='W18X50', Type='W', h='457', bf='191', tw='9.02', tf='14.5', k='24.7')

# %% [markdown]
# <br><br><br>
# ## 0. 재료 속성 Handler

# %%
class MaterialHandler:
    """Regist Fy and E"""
    fy = 0
    E = 0
    
    def registValue(self, fy, E):
        self.fy = fy
        self.E = E
    def getAttribute(self):
        return (self.fy, self.E)

# %%
####### 사용자 입력부 #######
input_fy = 345
input_E = 200000

# %%
matHandler = MaterialHandler()
matHandler.registValue(input_fy, input_E)
matHandler.getAttribute()
matHandler.fy
# Out:
# 345

# %% [markdown]
# <br><br><br>
# ## 1. 단면 속성 Handler

# %%
class SectionHandler:
    def __init__(self, matHandler:MaterialHandler, preSect:PreSection):
        (self.fy, self.E) = matHandler.getAttribute()
        
        self.ID = preSect.ID
        ( self.h, self.bf ) = ( float(preSect.h), float(preSect.bf) )
        ( self.tw, self.tf ) = ( float(preSect.tw), float(preSect.tf) )
        self.k = float(preSect.k)
        self.Type = preSect.Type

        self.Area = 2*self.tf*self.bf+(self.h-2*self.tf)*self.tw
        self.Weight = self.Area*77.22/10**6
        self.Ix = (2*(self.bf*self.tf**3/12+self.bf*self.tf*((self.h-2*self.tf)/2+self.tf/2)**2)+self.tw*(self.h-2*self.tf)**3/12) ## 단면2차모멘트
        self.Sx = self.Ix/(self.h/2) ## 탄성단면계수
        self.Zx = self.bf*self.tf*(self.h-self.tf)+0.25*(self.h-2*self.tf)**2*self.tw ## 소성단면계수
        self.rx = (self.Ix/self.Area)**0.5 ## 회전반경
        self.Iy = 2*(self.tf*(self.bf)**3/12)+(self.h-2*self.tf)*(self.tw)**3/12
        self.Sy = self.Iy/(self.bf/2)
        self.Zy = 0.5*(self.bf)**2*self.tf+0.25*(self.h-2*self.tf)*(self.tw)**2
        self.ry = (self.Iy/self.Area)**0.5
        self.Cw = (self.h-self.tf)**2*self.bf**3*self.tf/24 ## 뒤틀림 상수(mm6)
        self.J = (2*self.bf*self.tf**3+(self.h-self.tf)*self.tw**3)/3 ## 비틀림 상수(mm4)
        self.rts = ((self.Iy*self.Cw)**0.5/self.Sx)**0.5
        
    def __repr__(self):
        return str(
            [self.ID,
            self.Type,
            self.Area,
            self.Weight,
            ]
        )

# %%
sectHandler = SectionHandler(matHandler, targetSection) ## 재료핸들러와 단면 데이터 입력하여 섹션핸들러 개체 생성
print(sectHandler)
# Out:
# ['W18X50', 'W', 9399.56, 0.7258340231999999]

# %% [markdown]
# ## 2. Design Base Handler

# %%
class DesignBaseHandler:
    """dassfda"""
    def __init__(self, _shd:SectionHandler):
        (self.fy, self.E) = (_shd.fy, _shd.E)
        self.Type = _shd.Type
        self.Lp = self.findLp(_shd)
        self.Lr = self.findLr(_shd)
        self._shd = _shd
    

        
    def findLp(self, _shd:SectionHandler):
        return 1.76 * _shd.ry * (_shd.E)**0.5
    
    def findLr(self, _shd:SectionHandler):
        return 1.95 * _shd.rts * (_shd.E/0.75*_shd.fy) * (_shd.J/_shd.Sx*(_shd.h-_shd.tf) + ((_shd.J/_shd.Sx*(_shd.h-_shd.tf))**2+6.76*(0.7*_shd.fy/_shd.E)**2)**0.5)**0.5

# %%
baseHandler = DesignBaseHandler(sectHandler) ## 재료와 단면 데이터 입력하여 섹션핸들러 개체 생성

# %% [markdown]
# ## 3. Design Checker

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class LtbHandler:
    """latera-torsional buckling"""
    def __init__(self, mode, brace_idx): ## mode = "1p", "2p", "3p", "continuous"
        self.mode = mode
        self.brace_idx = brace_idx
        
    def findCb(self):
        _none = {
            "1p": [1.32],
            "2p": [1.14],
            "3p": [1.14],
            "continuous": [1.14],
        }
        
        _atLoad = {
            "1p": [[1.67, 1.67]],
            "2p": [[1.67, 1.00, 1.67]],
            "3p": [[1.67, 1.11, 1.11, 1.67]],
            "continuous": [
                [1.30, 1.30], 
                [1.45, 1.01, 1.45], 
                [1.52, 1.06, 1.06, 1.52], 
                [1.56, 1.12, 1.00, 1.12, 1.56]
            ],
        }
        if self.brace_idx == 0:
            result = _none[self.mode][self.brace_idx]
        else:
            result = _atLoad[self.mode][self.brace_idx-1]
        
        return result

# %%
ltbHandler = LtbHandler("continuous", 4)
ltbHandler.findCb()
# Out:
# [1.56, 1.12, 1.0, 1.12, 1.56]

# %%
class DesignChecker:
    """asdfasd"""
    def __init__(self, _bhd:DesignBaseHandler, _lhd:LtbHandler):
        (self.fy, self.E) = (_bhd.fy, _bhd.E)
        self.Type = _bhd.Type
        self.Lp = _bhd.Lp
        self.Lr = _bhd.Lr
        self._shd = _bhd._shd
    def registLength(self, length):
        self.length = length
    
    def registLoad(self, Wd, Wl):
        self.Wd = Wd
        self.Wl = Wl
        
    def registLb(self, Lb):
        self.Lb = Lb
    
    def findM(self):
        def chkCase():
            if self.Lb <= self.Lp:
                return "a"
            elif self.Lp < self.Lb <= self.Lr:
                return "b"
            else:
                return "c" ## Lb > Lr
        Ma = self.fy * self._shd.Zx
#         Mb = Cb
#         Mc
        
        return Ma
#         {
#             "a": Ma,
#             "b": "not yet",
#             "c": "not yet",
#         }

# %%
chkHandler = DesignChecker(baseHandler,ltbHandler)
chkHandler.registLb(1000) ## 생성된 핸들러에 비지지 길이 등록
chkHandler.registLoad(0.45, 0.75)
chkHandler.findM()
# Out:
# 565311366.15
