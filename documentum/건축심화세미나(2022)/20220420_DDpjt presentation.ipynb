# %%
#!pip install schedule

# %% [markdown]
# 장만규

# %% [markdown]
# <div
# style="
# font-style: normal;
# font-weight: bold;
# font-size: 2em;
# line-height: 1.5em;
# color: navy;
# font-family: 현대하모니;
# text-align: center;
# ">
#     <h1>
#         Try...Dynamic Document
#     </h1>
# </div>
# <br>
# <div
# style="
# color: navy;
# font-family: 현대하모니;
# text-align: center;
# ">
#     <h2>
#         부제: 주피터노트북의 활용
#     </h2>
# </div>

# %% [markdown]
# <br><br><br><br><br><br><br>
# <div
# style="
# font-style: normal;
# font-weight: normal;
# font-size: 1.5em;
# line-height: 1.0em;
# color: navy;
# font-family: 현대하모니_L;
# text-align: right;
# ">
#     <div>
#         발표자 - 장만규
#     </div>
# </div>
# <br><br><br><br>

# %%
# import schedule
# import time
from datetime import datetime
import pytz
tz = pytz.timezone('Asia/Seoul')
now = datetime.now(tz)
attendees = "참석자"

now
# Out:
# datetime.datetime(2022, 4, 20, 17, 7, 34, 552508, tzinfo=<DstTzInfo 'Asia/Seoul' KST+9:00:00 STD>)

# %% [markdown]
# <div
# style="
# font-style: normal;
# font-weight: normal;
# font-size: 1.5em;
# line-height: 1.0em;
# color: black;
# font-family: 현대하모니_L;
# text-align: ;
# ">
#     <div>
#         안녕하세요 {{attendees}} 여러분 반갑습니다.
#     </div>
# </div>
#
#
# <br>

# %% [markdown]
# 발표하고 있는 현재 시간은 지금 {{now.hour}} 시 {{now.minute}} 분 이네요.
#
# <br><br><br>
# 피피티 슬라이드처럼 보이는 이 문서에서 지금 시간을 알려드릴 수 있는 이유가 뭘까요?
#
# 제가 숫자를 적어놓고 발표타이밍을 절묘하게 조절했을까요?
# <br><br>
#
# 파이썬으로 작성된 코드를 실행하고, 그 결과를 일반적인 **문서양식에 섞어서 표현**할 수 있는 **주피터노트북**이란 프로그램이 있습니다.
#
# 이 문서는 주피터 노트북으로 작성되었기 때문에 이런 일들이 가능합니다.

# %% [markdown]
# ## 0. 금년도의 목표

# %% [markdown]
# 익숙한 문서를 주피터노트북으로 바꿔보는 것이 먼저 필요하다고 생각해서
#
#
# AISC 360 코드를 동적문서로 전환해 보는 것을 목표로 삼았습니다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1. 현재 진행상황

# %% [markdown]
# ### 대략적인 마스터 플랜

# %% [markdown]
# <div
# style="
# font-style: normal;
# font-weight: normal;
# font-size: 1.0em;
# line-height: 0.7em;
# color: red;
# font-family: 현대하모니_L;
# text-align: left;
# ">
#     <div>
#         전체 목차 중 필요 부분 선정
#     </div>
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# <br>
# <div
# style="
# font-style: normal;
# font-weight: normal;
# font-size: 1.0em;
# line-height: 0.7em;
# color: gray;
# font-family: 현대하모니_L;
# text-align: left;
# ">
#     <div>
#         [문서 중 code가 될 부분], [문서 양식이 될 부분] 분류작업
#     </div>
# </div>
#
# <br>
#
#
#
# ![image.png](attachment:image.png)
#
#
#
# <br>
# <div
# style="
# font-style: normal;
# font-weight: normal;
# font-size: 1.0em;
# line-height: 0.7em;
# color: gray;
# font-family: 현대하모니_L;
# text-align: cleft;
# ">
#     <div>
#         1차 초안 완성 후 피드백 보완<br><br>(변수, 함수 선언 스타일, 사용자 입력 UI 형식 표준 지정, 등등)
#     </div>
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
#
# <br>
# <div
# style="
# font-style: normal;
# font-weight: bold;
# font-size: 1.0em;
# line-height: 0.7em;
# color: black;
# font-family: 현대하모니_L;
# text-align: left;
# ">
#     <div>
#         피드백 내용 반영된 최종안 작성 팀 내 공유 <br><br>작성 & 공유 지침 포함하여 배포 예정
#     </div>
# </div>

# %% [markdown]
# ### 전환 대상 목차 선정 완료
#
# <br><br><br><br><br>
# 코드 전체를 한꺼번에 변환하는 것은 주피터노트북을 소개하고 도입한다는 목표에 비추었을때
# 다소 과하고 비효율 적이라 판단하여
#
# 그룹원들과 토의 후 전체 목차 중 자주 참고하게 되는 3개 목차 선정 후 변환에 착수 하기로 했습니다.

# %% [markdown]
# A. GENERAL PROVISIONS
# B. DESIGN REQUIREMENTS
# C. DESIGN FOR STABILITY
#
# **D. DESIGN OF MEMBERS FOR TENSION**
#
# **E. DESIGN OF MEMBERS FOR COMPRESSION**
#
# **F. DESIGN OF MEMBERS FOR FLEXURE**
#
# G. DESIGN OF MEMBERS FOR SHEAR
# H. DESIGN OF MEMBERS FOR COMBINED FORCES AND TORSION
# I. DESIGN OF COMPOSITE MEMBERS
# J. DESIGN OF CONNECTIONS
# K. ADDITIONAL REQUIREMENTS FOR HSS AND BOX-SECTION CONNECTIONS
# L. DESIGN FOR SERVICEABILITY
# M. FABRICATION AND ERECTION
# N. QUALITY CONTROL AND QUALITY ASSURANCE
# APPENDIX 1. DESIGN BY ADVANCED ANALYSIS
# APPENDIX 2. DESIGN FOR PONDING
# APPENDIX 3. FATIGUE
# APPENDIX 4. STRUCTURAL DESIGN FOR FIRE CONDITIONS
# APPENDIX 5. EVALUATION OF EXISTING STRUCTURES
# APPENDIX 6. MEMBER STABILITY BRACING
# APPENDIX 7. ALTERNATIVE METHODS OF DESIGN FOR STABILITY
# APPENDIX 8. APPROXIMATE SECOND-ORDER ANALYSIS

# %% [markdown]
# ## 2. 시작하기 위해 필요한것: 파이썬, 주피터노트북 (그리고 Docker)

# %% [markdown]
# ### Python
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Jupyter Notebook
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 이 두가지를 설치하는 게 부담스럽다면? 도커로 한큐에 설치하세요
# <br>
#
# **Autoway > 커뮤니티**로 가서 플랜트 건축을 검색하시면 건축심화세미나 커뮤니티가 개설되어 있는 걸 보실 수 있습니다.
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 도커사용 매뉴얼을 업로드 해 두었으니 참고하세요

# %% [markdown]
# ## 3. 여러가지 Skill들

# %% [markdown]
# ### 엑셀 데이터 연동

# %%
import numpy as np
import pandas as pd
# pd.set_option('display.max_rows', 2000)
# pd.set_option('display.max_columns', 2000)
# pd.set_option('display.width', 2000)

################# 사용자 입력부 #############################################################
fileName = 'Work Master_latest.xlsx'
sheetName ='Work Master'
headerRow = 2
naValues = '-'
#############################################################################################

df_excel = pd.read_excel(fileName, sheet_name = sheetName, header= headerRow, na_values= naValues)
dflength = len(df_excel)
df_excel
# Out:
#      Work Master\nCode Discipline Category(Large)  \
# 0                  NaN        NaN            Code
# 1       A00ZZ000-00001         AR             A00
# 2       A01ZZ001-00001         AR             A01
# 3       A01ZZ001-00002         AR             A01
# 4       A01ZZ001-00003         AR             A01
# ...                ...        ...             ...
# 1620    S04AE015-00001         SS             S04
# 1621    S05AF032-00001         SS             S05
# 1622    S05AG033-00001         SS             S05
# 1623    S05AG034-00001         SS             S05
# 1624    S05AG035-00001         SS             S05
#
#                              Unnamed: 3 Category(Middle)  \
# 0                           Description             Code
# 1                              AR-Dummy               ZZ
# 2                            Earth Work               ZZ
# 3                            Earth Work               ZZ
# 4                            Earth Work               ZZ
# ...

# %% [markdown]
# 이런 방식을 응용하면,
#
# 외부의 데이터를 끌어와 문서안에 담을 수 있습니다.
#
# 유관 부서 데이터를 관리할때, 새로 접수한 엑셀파일을 import 하기만 하면 됩니다.
# <br><br><br><br><br>
#
#
# 지금 임포트한 엑셀파일에서  WorkMaster 항목의 개수는 **{{dflength - 1}} 개** 이군요!
# <br><br><br><br>
# 지금 굵은 글씨로 표현된 데이터의 추출특성은 파일이 교체되는 즉시 리비전 됩니다.

# %% [markdown]
# ### 동적 User Interface

# %%
import ipywidgets as widgets
from ipywidgets import interact, interact_manual ## 동적 User Interface 라이브러리
import cufflinks as cf ## 시각화 라이브러리

cf.go_offline(connected=True)
df = pd.DataFrame(np.random.random([100,3]) * 10)
df.columns = ['Feature1','Feature2','Feature3']
df.head()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#    Feature1  Feature2  Feature3
# 0  4.919160  5.769295  6.973838
# 1  4.404061  5.180213  3.305215
# 2  0.804606  2.863377  3.318139
# 3  3.352232  6.839176  4.849126
# 4  6.090661  1.770326  6.416883

# %%
@interact
def show_data_more_than(column=['Feature1','Feature2','Feature3'], 
                        x=(0,10,1)):
    return df.loc[df[column] > x]
# Out:
# interactive(children=(Dropdown(description='column', options=('Feature1', 'Feature2', 'Feature3'), value='Feat…

# %%
@interact
def scatter_plot(x=list(df.select_dtypes('number').columns), 
                 y=list(df.select_dtypes('number').columns),
                 theme=list(cf.themes.THEMES.keys()), 
                 colorscale=list(cf.colors._scales_names.keys())):
    
    
    if x.title() == y.title():
        print('Can Not Use Same Value')
    else:
        title=f'{y.title()} vs {x.title()}'
        df.iplot(kind='scatter', x=x, y=y, mode='markers', 
                 xTitle=x.title(), yTitle=y.title(), 
                 #text='title',
                 title=f'{y.title()} vs {x.title()}',
                theme=theme, colorscale=colorscale)
# Out:
# interactive(children=(Dropdown(description='x', options=('Feature1', 'Feature2', 'Feature3'), value='Feature1'…

# %%
x = widgets.IntSlider(min=0, max=100, step=5, value=50)
y = widgets.IntSlider(min=0, max=100, step=5, value=50)

def update_y_range(*args):
    y.value = 100 - x.value
def update_x_range(*args):
    x.value = 100 - y.value
    
y.observe(update_x_range, 'value')
x.observe(update_y_range, 'value')

def printer(x,y):
    print(x,y)

interact(printer,
         x=x,
         y=y);
# Out:
# interactive(children=(IntSlider(value=50, description='x', step=5), IntSlider(value=50, description='y', step=…

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

x = np.linspace(0, 2*np.pi, num=5000)
y, y1, y2, y3 = [], [], [], []

# %%
param = 50

for i in range(1,param+1):
    y1.append([np.sin(i*j) for j in x])
    y2.append([np.cos(i*j)+np.cos(j) for j in x])
    y3.append([np.tan(i*j)+np.cos(j) for j in x])

y = [y1, y2, y3]

@interact(k=(0,param-1))
def f(k):
    fig = plt.figure(figsize=(10,10))
    
    # 타이틀을 배열에 저장한다. 
    title=['title1','title2','title3']
    
    # 그래프 간의 폭을 조정한다. 
    plt.subplots_adjust(wspace=0.2, hspace=0.6)

    for i in range(3):
        ax = fig.add_subplot(3, 1, i+1)
        ax.plot(x, y[i][k])
        ax.set_xlabel('x-axis label') # x축의 라벨 
        ax.set_ylabel('y-axis label') # y축의 라벨 
        ax.set_title(title[i]) # 타이틀 
        
    plt.show()
# Out:
# interactive(children=(IntSlider(value=24, description='k', max=49), Output()), _dom_classes=('widget-interact'…

# %% [markdown]
# ## 3. 참여 안내

# %% [markdown]
# 무제한
