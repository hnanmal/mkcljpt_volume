# %% [markdown]
# 3.3 Substation and Landing Point Locations
# The location of the Anma-do wind farm island substation where the export cable starts has not been finalised
# at this stage. The concept location of the island substation was provided by HEC and is given in Figure 3.1
# below.

# %% [markdown]
# ![image.png](attachment:afe7ee5a-91f3-4fdb-b116-4f805f492747.png)
