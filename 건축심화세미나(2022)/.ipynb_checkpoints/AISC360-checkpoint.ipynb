# %% [markdown]
# <div style="font-family: RIDIBatang; text-align: right"> ANSI/AISC 360-16<br>An American National Standard</div>

# %% [markdown]
# <hr/><br>
# <div style="font-family: RIDIBatang; text-align: right"> <h1><strong>Specification<br><br>for Structural Steel Buildings</strong></h1> </div>
# <br>
# <hr/>

# %% [markdown]
# <div style="font-family: RIDIBatang; text-align: right"> July 7, 2016</div>
# <div style="font-family: RIDIBatang; text-align: right"> Supersedes the Specification for Structural Steel Buildings<br>
# dated June 22, 2010 and all previous versions of this specification</div><br>
# <div style="font-family: RIDIBatang; text-align: right"> Approved by the AISC Committee on Specifications</div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div align="center"><img src="attachment:674dc8f2-d70e-4b4a-bc63-456661bdd3cf.png"></div>

# %% [markdown]
# <hr>

# %% [markdown]
# ## A. GENERAL PROVISIONS

# %% [markdown]
# ## B. DESIGN REQUIREMENTS

# %% [markdown]
# ## C. DESIGN FOR STABILITY

# %% [markdown]
# ## D. DESIGN OF MEMBERS FOR TENSION

# %% [markdown]
# ## E. DESIGN OF MEMBERS FOR COMPRESSION

# %% [markdown]
# ## F. DESIGN OF MEMBERS FOR FLEXURE

# %% [markdown]
# ## G. DESIGN OF MEMBERS FOR SHEAR

# %% [markdown]
# ## H. DESIGN OF MEMBERS FOR COMBINED FORCES AND TORSION

# %% [markdown]
# ## I. DESIGN OF COMPOSITE MEMBERS

# %% [markdown]
# ## J. DESIGN OF CONNECTIONS

# %% [markdown]
# ## K. ADDITIONAL REQUIREMENTS FOR HSS AND BOX-SECTION CONNECTIONS

# %% [markdown]
# ## L. DESIGN FOR SERVICEABILITY

# %% [markdown]
# ## M. FABRICATION AND ERECTION

# %% [markdown]
# ## N. QUALITY CONTROL AND QUALITY ASSURANCE

# %% [markdown]
# ## APPENDIX 1. DESIGN BY ADVANCED ANALYSIS

# %% [markdown]
# ## APPENDIX 2. DESIGN FOR PONDING

# %% [markdown]
# ## APPENDIX 3. FATIGUE

# %% [markdown]
# ## APPENDIX 4. STRUCTURAL DESIGN FOR FIRE CONDITIONS

# %% [markdown]
# ## APPENDIX 5. EVALUATION OF EXISTING STRUCTURES

# %% [markdown]
# ## APPENDIX 6. MEMBER STABILITY BRACING

# %% [markdown]
# ## APPENDIX 7. ALTERNATIVE METHODS OF DESIGN FOR STABILITY

# %% [markdown]
# ## APPENDIX 8. APPROXIMATE SECOND-ORDER ANALYSIS

# %%
a= "Hello Python Markdown"

# %% [markdown]
# a is **{{a}}**

# %% [markdown]
# ---

# %% [markdown]
# ## Agenda

# %% [markdown]
# <ol>
#     <li> <h3>주피터 노트북 설치 및 환경설정 방식 안내</h3>
#         <ul>
#             <li>docker 설치
#             <li>도커 이미지가 포함할 패키지 범위 결정
#         </ul>
#     <li> <h3>올해 가능한 현실적 목표 범위</h3>
#     <li> <h3>구성원 별 Role 협의</h3>
#     <li> <h3>Milestone 설정</h3>
# </ol>
